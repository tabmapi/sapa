# %% [markdown]
# # SAPA for ScF3 - Single Mode Refinement
#
# In this example, we will run SAPA for X-ray PDF data for ScF3, refining each mode on its own. It is recommended to use the Grouped Mode tutorial first, as that goes into more depth on the steps of the tutorial. In this tutorial, I will mainly highlight the differences of this method of operation from the Grouped Mode method.
#
# ScF3 is a formed from corner-sharing ScF6 octahedra, so shares a lot of similarities to the perovskite structure, such that the mode listing for ScF3 is a subset of those found for the ABX3 perovskite.
#
# As with the grouped mode tutorial, we have to tell the Python interpreter where to look for the SAPA scripts:

# %%
import sys
sys.path.append('..')

# %% [markdown]
# And then import the sapa script and create the sapa object:

# %%
import sapa as s

struc = s.sapa('ScF3_iso.cif')

# %% [markdown]
# Writing the input file for the Single Mode version requires an extra argument, as it writes the mode definitions out differently, but otherwise is exactly the same as the Grouped Mode version. The filename has been specified here, so we don't overwrite the grouped mode input file, and the cycles have been reduced significantly, as we are only refining one mode.

# %%
struc.write_inp(sample = 'ScF3_20',
               filenameformat = 'ScF3_##n##K_dofr.xye',
               isneutron = False,
               qmax = 21.0,
               dq = 0.08,
               startx = 1.0,
               finishx = 20.0,
               lattice = 'C',
               singlemode = True,
                cycles = 10,
               filename = 'ScF3_20_modes_single.inp')
# Out:
# Creating input file...
# 96
# 96
# ...ScF3_20_modes_single.inp written

# %% [markdown]
# The execution uses a different function, but only has one argument different from the grouped mode version. This is the 'unique_modes' argument. If this is specified, the script looks for which modes are effectively equivalent - i.e the same irrep, wyckoff position (w.r.t the input unit cell) and character, and then the script only executes one of those modes. This drastically reduces the number of modes that need to be executed. 'unique_modes' is set to True by default.
#
# As before, we still need to define temperatures;

# %%
temps = ['125', '140', '147', '152', '175', '200', '225', '250', '275', '325', '350', '375', '400']
#print(struc.filename)

struc.execute_single(temps, verbose=True)
# Out:
# Finding Topas executables...
# Creating Monitoring File...
# Executing only unique modes for each irrep...
# Executing mode 0 , irrep nomodes for temp 125
# Completed mode 0 (irrep nomodes) for temp 125. Process took 4.469836711883545s (0.07449727853139242 minutes)
# Estimated 0.4345674580997891 hours to completion.
# Executing mode 1 , irrep GM4- for temp 125
# Completed mode 1 (irrep GM4-) for temp 125. Process took 5.570072889328003s (0.09283454815546671 minutes)
# Estimated 0.48665672928094866 hours to completion.
# Executing mode 25 , irrep GM4- for temp 125
# Completed mode 25 (irrep GM4-) for temp 125. Process took 6.2463884353637695s (0.1041064739227295 minutes)
# Estimated 0.5247807145118714 hours to completion.
# Executing mode 28 , irrep GM4- for temp 125
# Completed mode 28 (irrep GM4-) for temp 125. Process took 4.743896961212158s (0.07906494935353597 minutes)
# Estimated 0.5067692822383509 hours to completion.
# Executing mode 4 , irrep R5+ for temp 125
# Completed mode 4 (irrep R5+) for temp 125. Process took 5.12840461730957s (0.08547341028849284 minutes)
# Estimated 0.5028264148235321 hours to completion.
# Executing mode 7 , irrep X1+ for temp 125
# Completed mode 7 (irrep X1+) for temp 125. Process took 5.4132466316223145s (0.09022077719370523 minutes)
# Estimated 0.5042725442184343 hours to completion.
# Executing mode 43 , irrep X1+ for temp 125
# Completed mode 43 (irrep X1+) for temp 125. Process took 4.765225887298584s (0.0794204314549764 minutes)
# Estimated 0.4960298735754831 hours to completion.
# Executing mode 10 , irrep X5+ for temp 125
# Completed mode 10 (irrep X5+) for temp 125. Process took 5.877572536468506s (0.09795954227447509 minutes)
# Estimated 0.5027646917353074 hours to completion.
# Executing mode 49 , irrep X5+ for temp 125
# Completed mode 49 (irrep X5+) for temp 125. Process took 6.1850504875183105s (0.10308417479197184 minutes)
# Estimated 0.5108856711122725 hours to completion.
# Executing mode 55 , irrep X5+ for temp 125
# Completed mode 55 (irrep X5+) for temp 125. Process took 4.481155633926392s (0.07468592723210653 minutes)
# Estimated 0.5008991700013479 hours to completion.
# Executing mode 16 , irrep M2- for temp 125
# Completed mode 16 (irrep M2-) for temp 125. Process took 4.829409122467041s (0.08049015204111735 minutes)
# Estimated 0.4954921305781663 hours to completion.
# Executing mode 88 , irrep M2- for temp 125
# Completed mode 88 (irrep M2-) for temp 125. Process took 7.23426365852356s (0.12057106097539266 minutes)
# Estimated 0.5096341085930666 hours to completion.
# Executing mode 19 , irrep M5- for temp 125
# Completed mode 19 (irrep M5-) for temp 125. Process took 5.551281213760376s (0.09252135356267294 minutes)
# Estimated 0.5091363679038153 hours to completion.
# Executing mode 91 , irrep M5- for temp 125
# Completed mode 91 (irrep M5-) for temp 125. Process took 5.296935081481934s (0.08828225135803222 minutes)
# Estimated 0.5067887566581605 hours to completion.
# Executing mode 31 , irrep GM5- for temp 125
# Completed mode 31 (irrep GM5-) for temp 125. Process took 4.865848064422607s (0.0810974677403768 minutes)
# Estimated 0.5018756582472059 hours to completion.
# Executing mode 34 , irrep R2- for temp 125
# Completed mode 34 (irrep R2-) for temp 125. Process took 10.29418396949768s (0.17156973282496135 minutes)
# Estimated 0.5289787949166365 hours to completion.
# Executing mode 35 , irrep R3- for temp 125
# Completed mode 35 (irrep R3-) for temp 125. Process took 9.894116163253784s (0.16490193605422973 minutes)
# Estimated 0.5503735394415512 hours to completion.
# Executing mode 37 , irrep R4- for temp 125
# Completed mode 37 (irrep R4-) for temp 125. Process took 5.461447477340698s (0.09102412462234497 minutes)
# Estimated 0.546306724316544 hours to completion.
# Executing mode 40 , irrep R5- for temp 125
# Completed mode 40 (irrep R5-) for temp 125. Process took 4.674076318740845s (0.07790127197901407 minutes)
# Estimated 0.5386865604969493 hours to completion.
# Executing mode 46 , irrep X2+ for temp 125
# Completed mode 46 (irrep X2+) for temp 125. Process took 4.512369632720947s (0.07520616054534912 minutes)
# Estimated 0.5309551760355632 hours to completion.
# Executing mode 61 , irrep X3- for temp 125
# Completed mode 61 (irrep X3-) for temp 125. Process took 7.142239332199097s (0.11903732220331828 minutes)
# Estimated 0.5353203290038638 hours to completion.
# Executing mode 64 , irrep X5- for temp 125
# Completed mode 64 (irrep X5-) for temp 125. Process took 4.8113720417022705s (0.08018953402837117 minutes)
# Estimated 0.5294257734038613 hours to completion.
# Executing mode 70 , irrep M1+ for temp 125
# Completed mode 70 (irrep M1+) for temp 125. Process took 4.874844551086426s (0.08124740918477376 minutes)
# Estimated 0.5241790081337454 hours to completion.
# Executing mode 73 , irrep M2+ for temp 125
# Completed mode 73 (irrep M2+) for temp 125. Process took 4.765382289886475s (0.07942303816477457 minutes)
# Estimated 0.51884234542648 hours to completion.
# Executing mode 76 , irrep M3+ for temp 125
# Completed mode 76 (irrep M3+) for temp 125. Process took 8.589555740356445s (0.1431592623392741 minutes)
# Estimated 0.5276787244055006 hours to completion.
# Executing mode 79 , irrep M4+ for temp 125
# Completed mode 79 (irrep M4+) for temp 125. Process took 7.766284704208374s (0.1294380784034729 minutes)
# Estimated 0.5327932644221518 hours to completion.
# Executing mode 82 , irrep M5+ for temp 125
# Completed mode 82 (irrep M5+) for temp 125. Process took 4.8283751010894775s (0.0804729183514913 minutes)
# Estimated 0.527576117515564 hours to completion.
# Executing mode 0 , irrep nomodes for temp 140
# Completed mode 0 (irrep nomodes) for temp 140. Process took 4.727609634399414s (0.0787934939066569 minutes)
# Estimated 0.5223129335235036 hours to completion.
# Executing mode 1 , irrep GM4- for temp 140
# Completed mode 1 (irrep GM4-) for temp 140. Process took 5.868247985839844s (0.09780413309733073 minutes)
# Estimated 0.5208402213191621 hours to completion.
# Executing mode 25 , irrep GM4- for temp 140
# Completed mode 25 (irrep GM4-) for temp 140. Process took 6.047006607055664s (0.10078344345092774 minutes)
# Estimated 0.5198883290158377 hours to completion.
# Executing mode 28 , irrep GM4- for temp 140
# Completed mode 28 (irrep GM4-) for temp 140. Process took 4.850607633590698s (0.08084346055984497 minutes)
# Estimated 0.5154589451342073 hours to completion.
# Executing mode 4 , irrep R5+ for temp 140
# Completed mode 4 (irrep R5+) for temp 140. Process took 6.078045129776001s (0.10130075216293336 minutes)
# Estimated 0.5146210795682338 hours to completion.
# Executing mode 7 , irrep X1+ for temp 140
# Completed mode 7 (irrep X1+) for temp 140. Process took 6.655257940292358s (0.1109209656715393 minutes)
# Estimated 0.515276734335254 hours to completion.
# Executing mode 43 , irrep X1+ for temp 140
# Completed mode 43 (irrep X1+) for temp 140. Process took 4.673692464828491s (0.07789487441380818 minutes)
# Estimated 0.5106530795767416 hours to completion.
# Executing mode 10 , irrep X5+ for temp 140
# Completed mode 10 (irrep X5+) for temp 140. Process took 6.1159656047821045s (0.10193276007970174 minutes)
# Estimated 0.5098365775289989 hours to completion.
# Executing mode 49 , irrep X5+ for temp 140
# Completed mode 49 (irrep X5+) for temp 140. Process took 8.158383131027222s (0.13597305218378702 minutes)
# Estimated 0.513935263786051 hours to completion.
# Executing mode 55 , irrep X5+ for temp 140
# Completed mode 55 (irrep X5+) for temp 140. Process took 4.442275762557983s (0.07403792937596639 minutes)
# Estimated 0.5089297081436123 hours to completion.
# Executing mode 16 , irrep M2- for temp 140
# Completed mode 16 (irrep M2-) for temp 140. Process took 5.61418080329895s (0.09356968005498251 minutes)
# Estimated 0.5068039896857669 hours to completion.
# Executing mode 88 , irrep M2- for temp 140
# Completed mode 88 (irrep M2-) for temp 140. Process took 7.781942129135132s (0.12969903548558553 minutes)
# Estimated 0.5095245557361179 hours to completion.
# Executing mode 19 , irrep M5- for temp 140
# Completed mode 19 (irrep M5-) for temp 140. Process took 6.539011716842651s (0.10898352861404419 minutes)
# Estimated 0.5093166265222762 hours to completion.
# Executing mode 91 , irrep M5- for temp 140
# Completed mode 91 (irrep M5-) for temp 140. Process took 4.696848392486572s (0.07828080654144287 minutes)
# Estimated 0.5051611934897053 hours to completion.
# Executing mode 31 , irrep GM5- for temp 140
# Completed mode 31 (irrep GM5-) for temp 140. Process took 4.888876914978027s (0.08148128191630045 minutes)
# Estimated 0.5015339498387442 hours to completion.
# Executing mode 34 , irrep R2- for temp 140
# Completed mode 34 (irrep R2-) for temp 140. Process took 6.74109673500061s (0.11235161225001017 minutes)
# Estimated 0.5016975466595139 hours to completion.
# Executing mode 35 , irrep R3- for temp 140
# Completed mode 35 (irrep R3-) for temp 140. Process took 11.543983697891235s (0.19239972829818724 minutes)
# Estimated 0.5110772180196012 hours to completion.
# Executing mode 37 , irrep R4- for temp 140
# Completed mode 37 (irrep R4-) for temp 140. Process took 4.942450761795044s (0.08237417936325073 minutes)
# Estimated 0.5074279345671335 hours to completion.
# Executing mode 40 , irrep R5- for temp 140
# Completed mode 40 (irrep R5-) for temp 140. Process took 4.764752149581909s (0.07941253582636515 minutes)
# Estimated 0.5035503411062674 hours to completion.
# Executing mode 46 , irrep X2+ for temp 140
# Completed mode 46 (irrep X2+) for temp 140. Process took 4.689818859100342s (0.07816364765167236 minutes)
# Estimated 0.4996467987583602 hours to completion.
# Executing mode 61 , irrep X3- for temp 140
# Completed mode 61 (irrep X3-) for temp 140. Process took 8.775607824325562s (0.14626013040542601 minutes)
# Estimated 0.5030159411537979 hours to completion.
# Executing mode 64 , irrep X5- for temp 140
# Completed mode 64 (irrep X5-) for temp 140. Process took 4.612178087234497s (0.07686963478724161 minutes)
# Estimated 0.4990202036087745 hours to completion.
# Executing mode 70 , irrep M1+ for temp 140
# Completed mode 70 (irrep M1+) for temp 140. Process took 4.975131034851074s (0.08291885058085123 minutes)
# Estimated 0.4957399871269862 hours to completion.
# Executing mode 73 , irrep M2+ for temp 140
# Completed mode 73 (irrep M2+) for temp 140. Process took 4.935570955276489s (0.08225951592127483 minutes)
# Estimated 0.4924695706055834 hours to completion.
# Executing mode 76 , irrep M3+ for temp 140
# Completed mode 76 (irrep M3+) for temp 140. Process took 9.184776067733765s (0.15307960112889607 minutes)
# Estimated 0.49605913370847704 hours to completion.
# Executing mode 79 , irrep M4+ for temp 140
# Completed mode 79 (irrep M4+) for temp 140. Process took 9.243030071258545s (0.1540505011876424 minutes)
# Estimated 0.4995079488374402 hours to completion.
# Executing mode 82 , irrep M5+ for temp 140
# Completed mode 82 (irrep M5+) for temp 140. Process took 4.156298875808716s (0.06927164793014526 minutes)
# Estimated 0.4949625422888332 hours to completion.
# Executing mode 0 , irrep nomodes for temp 147
# Completed mode 0 (irrep nomodes) for temp 147. Process took 4.310314655303955s (0.07183857758839925 minutes)
# Estimated 0.49077068624592796 hours to completion.
# Executing mode 1 , irrep GM4- for temp 147
# Completed mode 1 (irrep GM4-) for temp 147. Process took 5.7823944091796875s (0.0963732401529948 minutes)
# Estimated 0.4888398632466319 hours to completion.
# Executing mode 25 , irrep GM4- for temp 147
# Completed mode 25 (irrep GM4-) for temp 147. Process took 5.614030599594116s (0.09356717665990194 minutes)
# Estimated 0.48667920680073967 hours to completion.
# Executing mode 28 , irrep GM4- for temp 147
# Completed mode 28 (irrep GM4-) for temp 147. Process took 4.696000814437866s (0.0782666802406311 minutes)
# Estimated 0.48325105005868096 hours to completion.
# Executing mode 4 , irrep R5+ for temp 147
# Completed mode 4 (irrep R5+) for temp 147. Process took 6.6012585163116455s (0.11002097527186076 minutes)
# Estimated 0.4825141643894145 hours to completion.
# Executing mode 7 , irrep X1+ for temp 147
# Completed mode 7 (irrep X1+) for temp 147. Process took 7.018177270889282s (0.11696962118148804 minutes)
# Estimated 0.48230240102277866 hours to completion.
# Executing mode 43 , irrep X1+ for temp 147
# Completed mode 43 (irrep X1+) for temp 147. Process took 4.990863561630249s (0.08318105936050416 minutes)
# Estimated 0.47935642711886073 hours to completion.
# Executing mode 10 , irrep X5+ for temp 147
# Completed mode 10 (irrep X5+) for temp 147. Process took 6.316337585449219s (0.10527229309082031 minutes)
# Estimated 0.47817699119822527 hours to completion.
# Executing mode 49 , irrep X5+ for temp 147
# Completed mode 49 (irrep X5+) for temp 147. Process took 7.556931257247925s (0.1259488542874654 minutes)
# Estimated 0.47855465510534867 hours to completion.
# Executing mode 55 , irrep X5+ for temp 147
# Completed mode 55 (irrep X5+) for temp 147. Process took 5.075258255004883s (0.08458763758341471 minutes)
# Estimated 0.47576359855114586 hours to completion.
# Executing mode 16 , irrep M2- for temp 147
# Completed mode 16 (irrep M2-) for temp 147. Process took 7.140666246414185s (0.11901110410690308 minutes)
# Estimated 0.47553942992952136 hours to completion.
# Executing mode 88 , irrep M2- for temp 147
# Completed mode 88 (irrep M2-) for temp 147. Process took 6.029527425765991s (0.10049212376276652 minutes)
# Estimated 0.4739291422746398 hours to completion.
# Executing mode 19 , irrep M5- for temp 147
# Completed mode 19 (irrep M5-) for temp 147. Process took 6.665153741836548s (0.1110858956972758 minutes)
# Estimated 0.4730653425551963 hours to completion.
# Executing mode 91 , irrep M5- for temp 147
# Completed mode 91 (irrep M5-) for temp 147. Process took 4.765514612197876s (0.07942524353663126 minutes)
# Estimated 0.4699764250939578 hours to completion.
# Executing mode 31 , irrep GM5- for temp 147
# Completed mode 31 (irrep GM5-) for temp 147. Process took 4.958935022354126s (0.08264891703923544 minutes)
# Estimated 0.4671582553467313 hours to completion.
# Executing mode 34 , irrep R2- for temp 147
# Completed mode 34 (irrep R2-) for temp 147. Process took 7.9507060050964355s (0.13251176675160725 minutes)
# Estimated 0.4677173101958774 hours to completion.
# Executing mode 35 , irrep R3- for temp 147
# Completed mode 35 (irrep R3-) for temp 147. Process took 11.767920017242432s (0.19613200028737385 minutes)
# Estimated 0.47238001651793765 hours to completion.
# Executing mode 37 , irrep R4- for temp 147
# Completed mode 37 (irrep R4-) for temp 147. Process took 5.682988882064819s (0.09471648136774699 minutes)
# Estimated 0.4702726491043965 hours to completion.
# Executing mode 40 , irrep R5- for temp 147
# Completed mode 40 (irrep R5-) for temp 147. Process took 4.712484836578369s (0.07854141394297282 minutes)
# Estimated 0.4671531315499427 hours to completion.
# Executing mode 46 , irrep X2+ for temp 147
# Completed mode 46 (irrep X2+) for temp 147. Process took 5.0279860496521s (0.08379976749420166 minutes)
# Estimated 0.46441060120547495 hours to completion.
# Executing mode 61 , irrep X3- for temp 147
# Completed mode 61 (irrep X3-) for temp 147. Process took 6.6318519115448s (0.11053086519241333 minutes)
# Estimated 0.46334346798790826 hours to completion.
# Executing mode 64 , irrep X5- for temp 147
# Completed mode 64 (irrep X5-) for temp 147. Process took 5.181657314300537s (0.08636095523834228 minutes)
# Estimated 0.46079832359015593 hours to completion.
# Executing mode 70 , irrep M1+ for temp 147
# Completed mode 70 (irrep M1+) for temp 147. Process took 5.075349569320679s (0.08458915948867798 minutes)
# Estimated 0.4581768206170455 hours to completion.
# Executing mode 73 , irrep M2+ for temp 147
# Completed mode 73 (irrep M2+) for temp 147. Process took 6.169345378875732s (0.10282242298126221 minutes)
# Estimated 0.45664999349249735 hours to completion.
# Executing mode 76 , irrep M3+ for temp 147
# Completed mode 76 (irrep M3+) for temp 147. Process took 10.053407430648804s (0.1675567905108134 minutes)
# Estimated 0.45883314999179325 hours to completion.
# Executing mode 79 , irrep M4+ for temp 147
# Completed mode 79 (irrep M4+) for temp 147. Process took 8.187896251678467s (0.13646493752797445 minutes)
# Estimated 0.45913651804957123 hours to completion.
# Executing mode 82 , irrep M5+ for temp 147
# Completed mode 82 (irrep M5+) for temp 147. Process took 4.924343585968018s (0.08207239309946696 minutes)
# Estimated 0.45635442910371005 hours to completion.
# Executing mode 0 , irrep nomodes for temp 152
# Completed mode 0 (irrep nomodes) for temp 152. Process took 5.983441114425659s (0.09972401857376098 minutes)
# Estimated 0.45457193225945236 hours to completion.
# Executing mode 1 , irrep GM4- for temp 152
# Completed mode 1 (irrep GM4-) for temp 152. Process took 5.741205453872681s (0.09568675756454467 minutes)
# Estimated 0.4525750710846111 hours to completion.
# Executing mode 25 , irrep GM4- for temp 152
# Completed mode 25 (irrep GM4-) for temp 152. Process took 5.435391664505005s (0.09058986107508342 minutes)
# Estimated 0.45031776912865185 hours to completion.
# Executing mode 28 , irrep GM4- for temp 152
# Completed mode 28 (irrep GM4-) for temp 152. Process took 4.712237358093262s (0.07853728930155436 minutes)
# Estimated 0.44744943039245855 hours to completion.
# Executing mode 4 , irrep R5+ for temp 152
# Completed mode 4 (irrep R5+) for temp 152. Process took 7.081547975540161s (0.11802579959233601 minutes)
# Estimated 0.446645351597505 hours to completion.
# Executing mode 7 , irrep X1+ for temp 152
# Completed mode 7 (irrep X1+) for temp 152. Process took 6.169601678848267s (0.10282669464747111 minutes)
# Estimated 0.4450458463946521 hours to completion.
# Executing mode 43 , irrep X1+ for temp 152
# Completed mode 43 (irrep X1+) for temp 152. Process took 5.19677996635437s (0.0866129994392395 minutes)
# Estimated 0.442636130092421 hours to completion.
# Executing mode 10 , irrep X5+ for temp 152
# Completed mode 10 (irrep X5+) for temp 152. Process took 5.646681308746338s (0.0941113551457723 minutes)
# Estimated 0.4406160222457143 hours to completion.
# Executing mode 49 , irrep X5+ for temp 152
# Completed mode 49 (irrep X5+) for temp 152. Process took 6.278645753860474s (0.10464409589767457 minutes)
# Estimated 0.43911503209670383 hours to completion.
# Executing mode 55 , irrep X5+ for temp 152
# Completed mode 55 (irrep X5+) for temp 152. Process took 4.710989236831665s (0.07851648728052775 minutes)
# Estimated 0.436364527732607 hours to completion.
# Executing mode 16 , irrep M2- for temp 152
# Completed mode 16 (irrep M2-) for temp 152. Process took 6.465487003326416s (0.10775811672210693 minutes)
# Estimated 0.4350173946682382 hours to completion.
# Executing mode 88 , irrep M2- for temp 152
# Completed mode 88 (irrep M2-) for temp 152. Process took 6.663583993911743s (0.11105973323186238 minutes)
# Estimated 0.4338132646135105 hours to completion.
# Executing mode 19 , irrep M5- for temp 152
# Completed mode 19 (irrep M5-) for temp 152. Process took 5.635417699813843s (0.09392362833023071 minutes)
# Estimated 0.43181452412977284 hours to completion.
# Executing mode 91 , irrep M5- for temp 152
# Completed mode 91 (irrep M5-) for temp 152. Process took 4.572252988815308s (0.07620421648025513 minutes)
# Estimated 0.429029087535122 hours to completion.
# Executing mode 31 , irrep GM5- for temp 152
# Completed mode 31 (irrep GM5-) for temp 152. Process took 5.212359189987183s (0.08687265316645304 minutes)
# Estimated 0.4267475216545992 hours to completion.
# Executing mode 34 , irrep R2- for temp 152
# Completed mode 34 (irrep R2-) for temp 152. Process took 6.067699670791626s (0.1011283278465271 minutes)
# Estimated 0.4251053000984869 hours to completion.
# Executing mode 35 , irrep R3- for temp 152
# Completed mode 35 (irrep R3-) for temp 152. Process took 7.264057159423828s (0.12106761932373047 minutes)
# Estimated 0.42432012797685975 hours to completion.
# Executing mode 37 , irrep R4- for temp 152
# Completed mode 37 (irrep R4-) for temp 152. Process took 4.911454916000366s (0.08185758193333943 minutes)
# Estimated 0.42184659827839244 hours to completion.
# Executing mode 40 , irrep R5- for temp 152
# Completed mode 40 (irrep R5-) for temp 152. Process took 4.927255153656006s (0.08212091922760009 minutes)
# Estimated 0.41940626959005994 hours to completion.
# Executing mode 46 , irrep X2+ for temp 152
# Completed mode 46 (irrep X2+) for temp 152. Process took 4.648616790771484s (0.07747694651285807 minutes)
# Estimated 0.4167955785956976 hours to completion.
# Executing mode 61 , irrep X3- for temp 152
# Completed mode 61 (irrep X3-) for temp 152. Process took 6.377117872238159s (0.10628529787063598 minutes)
# Estimated 0.4153828628487836 hours to completion.
# Executing mode 64 , irrep X5- for temp 152
# Completed mode 64 (irrep X5-) for temp 152. Process took 4.779597282409668s (0.0796599547068278 minutes)
# Estimated 0.4128947215661519 hours to completion.
# Executing mode 70 , irrep M1+ for temp 152
# Completed mode 70 (irrep M1+) for temp 152. Process took 5.12847113609314s (0.08547451893488565 minutes)
# Estimated 0.4106590569516023 hours to completion.
# Executing mode 73 , irrep M2+ for temp 152
# Completed mode 73 (irrep M2+) for temp 152. Process took 5.077704668045044s (0.08462841113408406 minutes)
# Estimated 0.40840580316195413 hours to completion.
# Executing mode 76 , irrep M3+ for temp 152
# Completed mode 76 (irrep M3+) for temp 152. Process took 7.535242795944214s (0.12558737993240357 minutes)
# Estimated 0.4077462727981044 hours to completion.
# Executing mode 79 , irrep M4+ for temp 152
# Completed mode 79 (irrep M4+) for temp 152. Process took 4.8657426834106445s (0.0810957113901774 minutes)
# Estimated 0.4053689856989733 hours to completion.
# Executing mode 82 , irrep M5+ for temp 152
# Completed mode 82 (irrep M5+) for temp 152. Process took 5.361244201660156s (0.08935407002766928 minutes)
# Estimated 0.40332038134336473 hours to completion.
# Executing mode 0 , irrep nomodes for temp 175
# Completed mode 0 (irrep nomodes) for temp 175. Process took 5.869079113006592s (0.09781798521677652 minutes)
# Estimated 0.40159523140035275 hours to completion.
# Executing mode 1 , irrep GM4- for temp 175
# Completed mode 1 (irrep GM4-) for temp 175. Process took 6.316203594207764s (0.10527005990346273 minutes)
# Estimated 0.4001439196425255 hours to completion.
# Executing mode 25 , irrep GM4- for temp 175
# Completed mode 25 (irrep GM4-) for temp 175. Process took 6.1779234409332275s (0.10296539068222046 minutes)
# Estimated 0.39860409387239104 hours to completion.
# Executing mode 28 , irrep GM4- for temp 175
# Completed mode 28 (irrep GM4-) for temp 175. Process took 4.9511260986328125s (0.08251876831054687 minutes)
# Estimated 0.39633392666836104 hours to completion.
# Executing mode 4 , irrep R5+ for temp 175
# Completed mode 4 (irrep R5+) for temp 175. Process took 5.344835519790649s (0.08908059199651082 minutes)
# Estimated 0.39430993889871485 hours to completion.
# Executing mode 7 , irrep X1+ for temp 175
# Completed mode 7 (irrep X1+) for temp 175. Process took 6.76431941986084s (0.11273865699768067 minutes)
# Estimated 0.3931151439293086 hours to completion.
# Executing mode 43 , irrep X1+ for temp 175
# Completed mode 43 (irrep X1+) for temp 175. Process took 5.196117877960205s (0.08660196463267009 minutes)
# Estimated 0.3910144994938431 hours to completion.
# Executing mode 10 , irrep X5+ for temp 175
# Completed mode 10 (irrep X5+) for temp 175. Process took 6.832177639007568s (0.1138696273167928 minutes)
# Estimated 0.38984586283621664 hours to completion.
# Executing mode 49 , irrep X5+ for temp 175
# Completed mode 49 (irrep X5+) for temp 175. Process took 6.20004415512085s (0.10333406925201416 minutes)
# Estimated 0.38831357611550227 hours to completion.
# Executing mode 55 , irrep X5+ for temp 175
# Completed mode 55 (irrep X5+) for temp 175. Process took 4.565145015716553s (0.07608575026194254 minutes)
# Estimated 0.38588133853932105 hours to completion.
# Executing mode 16 , irrep M2- for temp 175
# Completed mode 16 (irrep M2-) for temp 175. Process took 7.20382022857666s (0.12006367047627767 minutes)
# Estimated 0.38489764080884636 hours to completion.
# Executing mode 88 , irrep M2- for temp 175
# Completed mode 88 (irrep M2-) for temp 175. Process took 6.532936334609985s (0.10888227224349975 minutes)
# Estimated 0.3835382504943345 hours to completion.
# Executing mode 19 , irrep M5- for temp 175
# Completed mode 19 (irrep M5-) for temp 175. Process took 6.433273553848267s (0.10722122589747111 minutes)
# Estimated 0.3821187116445151 hours to completion.
# Executing mode 91 , irrep M5- for temp 175
# Completed mode 91 (irrep M5-) for temp 175. Process took 4.759121894836426s (0.07931869824727376 minutes)
# Estimated 0.3798202415622215 hours to completion.
# Executing mode 31 , irrep GM5- for temp 175
# Completed mode 31 (irrep GM5-) for temp 175. Process took 5.134242057800293s (0.08557070096333821 minutes)
# Estimated 0.3777308006984431 hours to completion.
# Executing mode 34 , irrep R2- for temp 175
# Completed mode 34 (irrep R2-) for temp 175. Process took 6.116581439971924s (0.10194302399953206 minutes)
# Estimated 0.37615158951624317 hours to completion.
# Executing mode 35 , irrep R3- for temp 175
# Completed mode 35 (irrep R3-) for temp 175. Process took 6.617385387420654s (0.1102897564570109 minutes)
# Estimated 0.3748219757779439 hours to completion.
# Executing mode 37 , irrep R4- for temp 175
# Completed mode 37 (irrep R4-) for temp 175. Process took 4.757158994674683s (0.07928598324457804 minutes)
# Estimated 0.37256155848976164 hours to completion.
# Executing mode 40 , irrep R5- for temp 175
# Completed mode 40 (irrep R5-) for temp 175. Process took 5.914339780807495s (0.09857232968012491 minutes)
# Estimated 0.37088287607161285 hours to completion.
# Executing mode 46 , irrep X2+ for temp 175
# Completed mode 46 (irrep X2+) for temp 175. Process took 4.858668804168701s (0.08097781340281168 minutes)
# Estimated 0.3686938707499454 hours to completion.
# Executing mode 61 , irrep X3- for temp 175
# Completed mode 61 (irrep X3-) for temp 175. Process took 6.299521207809448s (0.10499202013015747 minutes)
# Estimated 0.36720665856849316 hours to completion.
# Executing mode 64 , irrep X5- for temp 175
# Completed mode 64 (irrep X5-) for temp 175. Process took 4.911548614501953s (0.08185914357503256 minutes)
# Estimated 0.36505997404125 hours to completion.
# Executing mode 70 , irrep M1+ for temp 175
# Completed mode 70 (irrep M1+) for temp 175. Process took 4.911214351654053s (0.08185357252756754 minutes)
# Estimated 0.36292507809233726 hours to completion.
# Executing mode 73 , irrep M2+ for temp 175
# Completed mode 73 (irrep M2+) for temp 175. Process took 4.800989627838135s (0.08001649379730225 minutes)
# Estimated 0.3607510609473243 hours to completion.
# Executing mode 76 , irrep M3+ for temp 175
# Completed mode 76 (irrep M3+) for temp 175. Process took 5.809360027313232s (0.09682266712188721 minutes)
# Estimated 0.35904879754348507 hours to completion.
# Executing mode 79 , irrep M4+ for temp 175
# Completed mode 79 (irrep M4+) for temp 175. Process took 5.27770471572876s (0.087961745262146 minutes)
# Estimated 0.3571086990937072 hours to completion.
# Executing mode 82 , irrep M5+ for temp 175
# Completed mode 82 (irrep M5+) for temp 175. Process took 4.673933267593384s (0.07789888779322306 minutes)
# Estimated 0.3549072810278998 hours to completion.
# Executing mode 0 , irrep nomodes for temp 200
# Completed mode 0 (irrep nomodes) for temp 200. Process took 7.533934831619263s (0.1255655805269877 minutes)
# Estimated 0.3539750677819541 hours to completion.
# Executing mode 1 , irrep GM4- for temp 200
# Completed mode 1 (irrep GM4-) for temp 200. Process took 6.637606859207153s (0.11062678098678588 minutes)
# Estimated 0.3526369946001026 hours to completion.
# Executing mode 25 , irrep GM4- for temp 200
# Completed mode 25 (irrep GM4-) for temp 200. Process took 6.393420934677124s (0.10655701557795207 minutes)
# Estimated 0.3511868990979332 hours to completion.
# Executing mode 28 , irrep GM4- for temp 200
# Completed mode 28 (irrep GM4-) for temp 200. Process took 5.03386926651001s (0.08389782110850016 minutes)
# Estimated 0.34915612592209255 hours to completion.
# Executing mode 4 , irrep R5+ for temp 200
# Completed mode 4 (irrep R5+) for temp 200. Process took 7.3803675174713135s (0.12300612529118855 minutes)
# Estimated 0.34811675147499355 hours to completion.
# Executing mode 7 , irrep X1+ for temp 200
# Completed mode 7 (irrep X1+) for temp 200. Process took 7.972639560699463s (0.13287732601165772 minutes)
# Estimated 0.34730807027072774 hours to completion.
# Executing mode 43 , irrep X1+ for temp 200
# Completed mode 43 (irrep X1+) for temp 200. Process took 4.995684862136841s (0.08326141436894735 minutes)
# Estimated 0.3452624831461757 hours to completion.
# Executing mode 10 , irrep X5+ for temp 200
# Completed mode 10 (irrep X5+) for temp 200. Process took 8.563390493392944s (0.1427231748898824 minutes)
# Estimated 0.3446675946014096 hours to completion.
# Executing mode 49 , irrep X5+ for temp 200
# Completed mode 49 (irrep X5+) for temp 200. Process took 6.084042549133301s (0.10140070915222169 minutes)
# Estimated 0.34305791321727963 hours to completion.
# Executing mode 55 , irrep X5+ for temp 200
# Completed mode 55 (irrep X5+) for temp 200. Process took 4.62572455406189s (0.07709540923436482 minutes)
# Estimated 0.340871619024496 hours to completion.
# Executing mode 16 , irrep M2- for temp 200
# Completed mode 16 (irrep M2-) for temp 200. Process took 8.28310751914978s (0.13805179198582967 minutes)
# Estimated 0.340124163067867 hours to completion.
# Executing mode 88 , irrep M2- for temp 200
# Completed mode 88 (irrep M2-) for temp 200. Process took 6.568867921829224s (0.10948113203048707 minutes)
# Estimated 0.3386947543334529 hours to completion.
# Executing mode 19 , irrep M5- for temp 200
# Completed mode 19 (irrep M5-) for temp 200. Process took 9.073359966278076s (0.1512226661046346 minutes)
# Estimated 0.33821423053159727 hours to completion.
# Executing mode 91 , irrep M5- for temp 200
# Completed mode 91 (irrep M5-) for temp 200. Process took 4.5955564975738525s (0.07659260829289755 minutes)
# Estimated 0.33602005413981356 hours to completion.
# Executing mode 31 , irrep GM5- for temp 200
# Completed mode 31 (irrep GM5-) for temp 200. Process took 5.158797740936279s (0.08597996234893798 minutes)
# Estimated 0.3340477637608846 hours to completion.
# Executing mode 34 , irrep R2- for temp 200
# Completed mode 34 (irrep R2-) for temp 200. Process took 6.484068155288696s (0.10806780258814494 minutes)
# Estimated 0.33257020660144954 hours to completion.
# Executing mode 35 , irrep R3- for temp 200
# Completed mode 35 (irrep R3-) for temp 200. Process took 7.365003347396851s (0.12275005578994751 minutes)
# Estimated 0.33140876124476826 hours to completion.
# Executing mode 37 , irrep R4- for temp 200
# Completed mode 37 (irrep R4-) for temp 200. Process took 5.412747383117676s (0.0902124563852946 minutes)
# Estimated 0.3295339638890784 hours to completion.
# Executing mode 40 , irrep R5- for temp 200
# Completed mode 40 (irrep R5-) for temp 200. Process took 4.826558828353882s (0.08044264713923137 minutes)
# Estimated 0.32745569232867394 hours to completion.
# Executing mode 46 , irrep X2+ for temp 200
# Completed mode 46 (irrep X2+) for temp 200. Process took 4.980211496353149s (0.08300352493921916 minutes)
# Estimated 0.32544090886953486 hours to completion.
# Executing mode 61 , irrep X3- for temp 200
# Completed mode 61 (irrep X3-) for temp 200. Process took 6.56918740272522s (0.109486456712087 minutes)
# Estimated 0.3239859479169051 hours to completion.
# Executing mode 64 , irrep X5- for temp 200
# Completed mode 64 (irrep X5-) for temp 200. Process took 4.928122282028198s (0.08213537136713664 minutes)
# Estimated 0.32196299459102384 hours to completion.
# Executing mode 70 , irrep M1+ for temp 200
# Completed mode 70 (irrep M1+) for temp 200. Process took 6.600079774856567s (0.11000132958094279 minutes)
# Estimated 0.32051563341615913 hours to completion.
# Executing mode 73 , irrep M2+ for temp 200
# Completed mode 73 (irrep M2+) for temp 200. Process took 4.758019924163818s (0.07930033206939698 minutes)
# Estimated 0.31844553525592795 hours to completion.
# Executing mode 76 , irrep M3+ for temp 200
# Completed mode 76 (irrep M3+) for temp 200. Process took 6.153106212615967s (0.10255177021026611 minutes)
# Estimated 0.3168473991581963 hours to completion.
# Executing mode 79 , irrep M4+ for temp 200
# Completed mode 79 (irrep M4+) for temp 200. Process took 7.471776485443115s (0.12452960809071859 minutes)
# Estimated 0.3156801597466544 hours to completion.
# Executing mode 82 , irrep M5+ for temp 200
# Completed mode 82 (irrep M5+) for temp 200. Process took 4.712558746337891s (0.07854264577229818 minutes)
# Estimated 0.3136075163880984 hours to completion.
# Executing mode 0 , irrep nomodes for temp 225
# Completed mode 0 (irrep nomodes) for temp 225. Process took 8.062589168548584s (0.1343764861424764 minutes)
# Estimated 0.31261753089263805 hours to completion.
# Executing mode 1 , irrep GM4- for temp 225
# Completed mode 1 (irrep GM4-) for temp 225. Process took 5.134762287139893s (0.08557937145233155 minutes)
# Estimated 0.3106849625557257 hours to completion.
# Executing mode 25 , irrep GM4- for temp 225
# Completed mode 25 (irrep GM4-) for temp 225. Process took 6.563822984695435s (0.10939704974492391 minutes)
# Estimated 0.3092060141804242 hours to completion.
# Executing mode 28 , irrep GM4- for temp 225
# Completed mode 28 (irrep GM4-) for temp 225. Process took 4.982427597045898s (0.08304045995076498 minutes)
# Estimated 0.3072333620494628 hours to completion.
# Executing mode 4 , irrep R5+ for temp 225
# Completed mode 4 (irrep R5+) for temp 225. Process took 8.475942611694336s (0.1412657101949056 minutes)
# Estimated 0.30633696574492214 hours to completion.
# Executing mode 7 , irrep X1+ for temp 225
# Completed mode 7 (irrep X1+) for temp 225. Process took 8.685482025146484s (0.1447580337524414 minutes)
# Estimated 0.3054866142168878 hours to completion.
# Executing mode 43 , irrep X1+ for temp 225
# Completed mode 43 (irrep X1+) for temp 225. Process took 4.881565809249878s (0.08135943015416464 minutes)
# Estimated 0.30347985048579357 hours to completion.
# Executing mode 10 , irrep X5+ for temp 225
# Completed mode 10 (irrep X5+) for temp 225. Process took 8.02163314819336s (0.13369388580322267 minutes)
# Estimated 0.3024094229566506 hours to completion.
# Executing mode 49 , irrep X5+ for temp 225
# Completed mode 49 (irrep X5+) for temp 225. Process took 6.231698989868164s (0.10386164983113606 minutes)
# Estimated 0.30080208130050123 hours to completion.
# Executing mode 55 , irrep X5+ for temp 225
# Completed mode 55 (irrep X5+) for temp 225. Process took 4.580580472946167s (0.07634300788243611 minutes)
# Estimated 0.2987159916589119 hours to completion.
# Executing mode 16 , irrep M2- for temp 225
# Completed mode 16 (irrep M2-) for temp 225. Process took 8.28463625907898s (0.13807727098464967 minutes)
# Estimated 0.29769795053113934 hours to completion.
# Executing mode 88 , irrep M2- for temp 225
# Completed mode 88 (irrep M2-) for temp 225. Process took 6.452991962432861s (0.10754986604054768 minutes)
# Estimated 0.2961475971158437 hours to completion.
# Executing mode 19 , irrep M5- for temp 225
# Completed mode 19 (irrep M5-) for temp 225. Process took 9.603600978851318s (0.16006001631418865 minutes)
# Estimated 0.29547464647444466 hours to completion.
# Executing mode 91 , irrep M5- for temp 225
# Completed mode 91 (irrep M5-) for temp 225. Process took 5.060230731964111s (0.08433717886606852 minutes)
# Estimated 0.2935241520348372 hours to completion.
# Executing mode 31 , irrep GM5- for temp 225
# Completed mode 31 (irrep GM5-) for temp 225. Process took 4.9437255859375s (0.08239542643229167 minutes)
# Estimated 0.2915480003496123 hours to completion.
# Executing mode 34 , irrep R2- for temp 225
# Completed mode 34 (irrep R2-) for temp 225. Process took 8.106183528900146s (0.13510305881500245 minutes)
# Estimated 0.2904324074426245 hours to completion.
# Executing mode 35 , irrep R3- for temp 225
# Completed mode 35 (irrep R3-) for temp 225. Process took 7.8738274574279785s (0.13123045762379965 minutes)
# Estimated 0.2892421010930223 hours to completion.
# Executing mode 37 , irrep R4- for temp 225
# Completed mode 37 (irrep R4-) for temp 225. Process took 4.897992372512817s (0.08163320620854696 minutes)
# Estimated 0.28725542861885495 hours to completion.
# Executing mode 40 , irrep R5- for temp 225
# Completed mode 40 (irrep R5-) for temp 225. Process took 4.6118128299713135s (0.07686354716618855 minutes)
# Estimated 0.28520101141607634 hours to completion.
# Executing mode 46 , irrep X2+ for temp 225
# Completed mode 46 (irrep X2+) for temp 225. Process took 5.653069019317627s (0.09421781698862712 minutes)
# Estimated 0.28342367063912133 hours to completion.
# Executing mode 61 , irrep X3- for temp 225
# Completed mode 61 (irrep X3-) for temp 225. Process took 7.165801286697388s (0.11943002144495646 minutes)
# Estimated 0.2820343531415762 hours to completion.
# Executing mode 64 , irrep X5- for temp 225
# Completed mode 64 (irrep X5-) for temp 225. Process took 4.866154909133911s (0.08110258181889853 minutes)
# Estimated 0.2800587290896166 hours to completion.
# Executing mode 70 , irrep M1+ for temp 225
# Completed mode 70 (irrep M1+) for temp 225. Process took 4.944251298904419s (0.08240418831507365 minutes)
# Estimated 0.2781093155242302 hours to completion.
# Executing mode 73 , irrep M2+ for temp 225
# Completed mode 73 (irrep M2+) for temp 225. Process took 4.928526878356934s (0.08214211463928223 minutes)
# Estimated 0.27616222087414033 hours to completion.
# Executing mode 76 , irrep M3+ for temp 225
# Completed mode 76 (irrep M3+) for temp 225. Process took 6.888695001602173s (0.11481158336003622 minutes)
# Estimated 0.27469883032377745 hours to completion.
# Executing mode 79 , irrep M4+ for temp 225
# Completed mode 79 (irrep M4+) for temp 225. Process took 7.1775312423706055s (0.11962552070617676 minutes)
# Estimated 0.27330021419599826 hours to completion.
# Executing mode 82 , irrep M5+ for temp 225
# Completed mode 82 (irrep M5+) for temp 225. Process took 5.35609769821167s (0.08926829497019449 minutes)
# Estimated 0.2714616256100791 hours to completion.
# Executing mode 0 , irrep nomodes for temp 250
# Completed mode 0 (irrep nomodes) for temp 250. Process took 9.008170366287231s (0.15013617277145386 minutes)
# Estimated 0.27048635477559607 hours to completion.
# Executing mode 1 , irrep GM4- for temp 250
# Completed mode 1 (irrep GM4-) for temp 250. Process took 7.390010595321655s (0.12316684325536092 minutes)
# Estimated 0.2691185592842213 hours to completion.
# Executing mode 25 , irrep GM4- for temp 250
# Completed mode 25 (irrep GM4-) for temp 250. Process took 6.848715543746948s (0.11414525906244914 minutes)
# Estimated 0.26761911187320947 hours to completion.
# Executing mode 28 , irrep GM4- for temp 250
# Completed mode 28 (irrep GM4-) for temp 250. Process took 5.050530433654785s (0.08417550722757976 minutes)
# Estimated 0.26570657485781835 hours to completion.
# Executing mode 4 , irrep R5+ for temp 250
# Completed mode 4 (irrep R5+) for temp 250. Process took 7.382554531097412s (0.1230425755182902 minutes)
# Estimated 0.2643235295218973 hours to completion.
# Executing mode 7 , irrep X1+ for temp 250
# Completed mode 7 (irrep X1+) for temp 250. Process took 8.807920217514038s (0.14679867029190063 minutes)
# Estimated 0.2632503842777676 hours to completion.
# Executing mode 43 , irrep X1+ for temp 250
# Completed mode 43 (irrep X1+) for temp 250. Process took 4.959191560745239s (0.08265319267908731 minutes)
# Estimated 0.26131776888557035 hours to completion.
# Executing mode 10 , irrep X5+ for temp 250
# Completed mode 10 (irrep X5+) for temp 250. Process took 8.328896284103394s (0.1388149380683899 minutes)
# Estimated 0.2601225068141563 hours to completion.
# Executing mode 49 , irrep X5+ for temp 250
# Completed mode 49 (irrep X5+) for temp 250. Process took 7.212848901748657s (0.12021414836247762 minutes)
# Estimated 0.25867639295380523 hours to completion.
# Executing mode 55 , irrep X5+ for temp 250
# Completed mode 55 (irrep X5+) for temp 250. Process took 5.035719633102417s (0.08392866055170695 minutes)
# Estimated 0.25676275071985954 hours to completion.
# Executing mode 16 , irrep M2- for temp 250
# Completed mode 16 (irrep M2-) for temp 250. Process took 8.205660104751587s (0.13676100174585978 minutes)
# Estimated 0.25551906375818784 hours to completion.
# Executing mode 88 , irrep M2- for temp 250
# Completed mode 88 (irrep M2-) for temp 250. Process took 6.36379861831665s (0.1060633103052775 minutes)
# Estimated 0.2538832596087733 hours to completion.
# Executing mode 19 , irrep M5- for temp 250
# Completed mode 19 (irrep M5-) for temp 250. Process took 7.318439960479736s (0.12197399934132894 minutes)
# Estimated 0.25244175104877214 hours to completion.
# Executing mode 91 , irrep M5- for temp 250
# Completed mode 91 (irrep M5-) for temp 250. Process took 4.826888561248779s (0.08044814268747966 minutes)
# Estimated 0.25048983249236273 hours to completion.
# Executing mode 31 , irrep GM5- for temp 250
# Completed mode 31 (irrep GM5-) for temp 250. Process took 4.7821033000946045s (0.07970172166824341 minutes)
# Estimated 0.24853494090095066 hours to completion.
# Executing mode 34 , irrep R2- for temp 250
# Completed mode 34 (irrep R2-) for temp 250. Process took 7.751011848449707s (0.12918353080749512 minutes)
# Estimated 0.24717350684465755 hours to completion.
# Executing mode 35 , irrep R3- for temp 250
# Completed mode 35 (irrep R3-) for temp 250. Process took 7.889775276184082s (0.13149625460306805 minutes)
# Estimated 0.2458315185792624 hours to completion.
# Executing mode 37 , irrep R4- for temp 250
# Completed mode 37 (irrep R4-) for temp 250. Process took 4.9130940437316895s (0.0818849007288615 minutes)
# Estimated 0.24390611736094892 hours to completion.
# Executing mode 40 , irrep R5- for temp 250
# Completed mode 40 (irrep R5-) for temp 250. Process took 4.843087196350098s (0.08071811993916829 minutes)
# Estimated 0.2419727376724283 hours to completion.
# Executing mode 46 , irrep X2+ for temp 250
# Completed mode 46 (irrep X2+) for temp 250. Process took 5.214305877685547s (0.08690509796142579 minutes)
# Estimated 0.2401150454003275 hours to completion.
# Executing mode 61 , irrep X3- for temp 250
# Completed mode 61 (irrep X3-) for temp 250. Process took 7.234025239944458s (0.12056708733240763 minutes)
# Estimated 0.23863794466616614 hours to completion.
# Executing mode 64 , irrep X5- for temp 250
# Completed mode 64 (irrep X5-) for temp 250. Process took 5.614171266555786s (0.0935695211092631 minutes)
# Estimated 0.2368572466683551 hours to completion.
# Executing mode 70 , irrep M1+ for temp 250
# Completed mode 70 (irrep M1+) for temp 250. Process took 4.964808940887451s (0.08274681568145752 minutes)
# Estimated 0.23496036853399166 hours to completion.
# Executing mode 73 , irrep M2+ for temp 250
# Completed mode 73 (irrep M2+) for temp 250. Process took 4.5116236209869385s (0.07519372701644897 minutes)
# Estimated 0.2329867928651204 hours to completion.
# Executing mode 76 , irrep M3+ for temp 250
# Completed mode 76 (irrep M3+) for temp 250. Process took 5.6462812423706055s (0.09410468737284343 minutes)
# Estimated 0.23122172523324735 hours to completion.
# Executing mode 79 , irrep M4+ for temp 250
# Completed mode 79 (irrep M4+) for temp 250. Process took 7.256829023361206s (0.12094715038935343 minutes)
# Estimated 0.22974147726891886 hours to completion.
# Executing mode 82 , irrep M5+ for temp 250
# Completed mode 82 (irrep M5+) for temp 250. Process took 5.931144714355469s (0.09885241190592448 minutes)
# Estimated 0.22802611709468895 hours to completion.
# Executing mode 0 , irrep nomodes for temp 275
# Completed mode 0 (irrep nomodes) for temp 275. Process took 8.885854959487915s (0.14809758265813192 minutes)
# Estimated 0.22681820632736316 hours to completion.
# Executing mode 1 , irrep GM4- for temp 275
# Completed mode 1 (irrep GM4-) for temp 275. Process took 7.257201433181763s (0.12095335721969605 minutes)
# Estimated 0.22532272462299233 hours to completion.
# Executing mode 25 , irrep GM4- for temp 275
# Completed mode 25 (irrep GM4-) for temp 275. Process took 6.67946195602417s (0.11132436593373617 minutes)
# Estimated 0.22372576074513126 hours to completion.
# Executing mode 28 , irrep GM4- for temp 275
# Completed mode 28 (irrep GM4-) for temp 275. Process took 6.68691349029541s (0.11144855817159018 minutes)
# Estimated 0.2221276799064092 hours to completion.
# Executing mode 4 , irrep R5+ for temp 275
# Completed mode 4 (irrep R5+) for temp 275. Process took 6.016132593154907s (0.10026887655258179 minutes)
# Estimated 0.22041764687868506 hours to completion.
# Executing mode 7 , irrep X1+ for temp 275
# Completed mode 7 (irrep X1+) for temp 275. Process took 9.024874925613403s (0.1504145820935567 minutes)
# Estimated 0.219193609513499 hours to completion.
# Executing mode 43 , irrep X1+ for temp 275
# Completed mode 43 (irrep X1+) for temp 275. Process took 4.744189262390137s (0.0790698210398356 minutes)
# Estimated 0.2172755456837957 hours to completion.
# Executing mode 10 , irrep X5+ for temp 275
# Completed mode 10 (irrep X5+) for temp 275. Process took 9.610628128051758s (0.1601771354675293 minutes)
# Estimated 0.21612925692476215 hours to completion.
# Executing mode 49 , irrep X5+ for temp 275
# Completed mode 49 (irrep X5+) for temp 275. Process took 8.335326671600342s (0.13892211119333903 minutes)
# Estimated 0.21477104722658794 hours to completion.
# Executing mode 55 , irrep X5+ for temp 275
# Completed mode 55 (irrep X5+) for temp 275. Process took 4.722676515579224s (0.07871127525965373 minutes)
# Estimated 0.21284932620464408 hours to completion.
# Executing mode 16 , irrep M2- for temp 275
# Completed mode 16 (irrep M2-) for temp 275. Process took 5.655379772186279s (0.09425632953643799 minutes)
# Estimated 0.2110745046469025 hours to completion.
# Executing mode 88 , irrep M2- for temp 275
# Completed mode 88 (irrep M2-) for temp 275. Process took 7.593033790588379s (0.12655056317647298 minutes)
# Estimated 0.20959183635418874 hours to completion.
# Executing mode 19 , irrep M5- for temp 275
# Completed mode 19 (irrep M5-) for temp 275. Process took 5.961286783218384s (0.0993547797203064 minutes)
# Estimated 0.207862219989213 hours to completion.
# Executing mode 91 , irrep M5- for temp 275
# Completed mode 91 (irrep M5-) for temp 275. Process took 5.729267835617065s (0.09548779726028442 minutes)
# Estimated 0.20609933837254846 hours to completion.
# Executing mode 31 , irrep GM5- for temp 275
# Completed mode 31 (irrep GM5-) for temp 275. Process took 5.011146068572998s (0.0835191011428833 minutes)
# Estimated 0.20423431582265086 hours to completion.
# Executing mode 34 , irrep R2- for temp 275
# Completed mode 34 (irrep R2-) for temp 275. Process took 10.81028437614441s (0.1801714062690735 minutes)
# Estimated 0.20319963729672733 hours to completion.
# Executing mode 35 , irrep R3- for temp 275
# Completed mode 35 (irrep R3-) for temp 275. Process took 9.639094114303589s (0.1606515685717265 minutes)
# Estimated 0.20198330481960822 hours to completion.
# Executing mode 37 , irrep R4- for temp 275
# Completed mode 37 (irrep R4-) for temp 275. Process took 4.927380800247192s (0.08212301333745321 minutes)
# Estimated 0.2001000788807869 hours to completion.
# Executing mode 40 , irrep R5- for temp 275
# Completed mode 40 (irrep R5-) for temp 275. Process took 4.826481103897095s (0.08044135173161825 minutes)
# Estimated 0.1982073967958455 hours to completion.
# Executing mode 46 , irrep X2+ for temp 275
# Completed mode 46 (irrep X2+) for temp 275. Process took 4.826981544494629s (0.08044969240824382 minutes)
# Estimated 0.19631946035529257 hours to completion.
# Executing mode 61 , irrep X3- for temp 275
# Completed mode 61 (irrep X3-) for temp 275. Process took 7.201799392700195s (0.12002998987833659 minutes)
# Estimated 0.19475345126351895 hours to completion.
# Executing mode 64 , irrep X5- for temp 275
# Completed mode 64 (irrep X5-) for temp 275. Process took 4.6108033657073975s (0.07684672276178996 minutes)
# Estimated 0.1928420746596365 hours to completion.
# Executing mode 70 , irrep M1+ for temp 275
# Completed mode 70 (irrep M1+) for temp 275. Process took 4.86428165435791s (0.08107136090596517 minutes)
# Estimated 0.19096897080464456 hours to completion.
# Executing mode 73 , irrep M2+ for temp 275
# Completed mode 73 (irrep M2+) for temp 275. Process took 4.825993776321411s (0.08043322960535686 minutes)
# Estimated 0.18909529730843175 hours to completion.
# ...
# Completed mode 1 (irrep GM4-) for temp 350. Process took 7.165187835693359s (0.119419797261556 minutes)
# Estimated 0.1360054033098657 hours to completion.
# Executing mode 25 , irrep GM4- for temp 350
# Completed mode 25 (irrep GM4-) for temp 350. Process took 9.439433574676514s (0.15732389291127521 minutes)
# Estimated 0.13454109521139235 hours to completion.
# Executing mode 28 , irrep GM4- for temp 350
# Completed mode 28 (irrep GM4-) for temp 350. Process took 4.865279197692871s (0.08108798662821452 minutes)
# Estimated 0.13271127034906247 hours to completion.
# Executing mode 4 , irrep R5+ for temp 350
# Completed mode 4 (irrep R5+) for temp 350. Process took 7.264667749404907s (0.12107779582341512 minutes)
# Estimated 0.13106911994182702 hours to completion.
# Executing mode 7 , irrep X1+ for temp 350
# Completed mode 7 (irrep X1+) for temp 350. Process took 8.905701875686646s (0.14842836459477743 minutes)
# Estimated 0.12954811658260326 hours to completion.
# Executing mode 43 , irrep X1+ for temp 350
# Completed mode 43 (irrep X1+) for temp 350. Process took 4.842417001724243s (0.08070695002873739 minutes)
# Estimated 0.12771870642410338 hours to completion.
# Executing mode 10 , irrep X5+ for temp 350
# Completed mode 10 (irrep X5+) for temp 350. Process took 6.013477087020874s (0.10022461811701457 minutes)
# Estimated 0.12597819944842162 hours to completion.
# Executing mode 49 , irrep X5+ for temp 350
# Completed mode 49 (irrep X5+) for temp 350. Process took 7.802114248275757s (0.1300352374712626 minutes)
# Estimated 0.12436641267550891 hours to completion.
# Executing mode 55 , irrep X5+ for temp 350
# Completed mode 55 (irrep X5+) for temp 350. Process took 4.580212354660034s (0.07633687257766723 minutes)
# Estimated 0.12252371876154627 hours to completion.
# Executing mode 16 , irrep M2- for temp 350
# Completed mode 16 (irrep M2-) for temp 350. Process took 6.979452610015869s (0.11632421016693115 minutes)
# Estimated 0.12085110569905273 hours to completion.
# Executing mode 88 , irrep M2- for temp 350
# Completed mode 88 (irrep M2-) for temp 350. Process took 6.752478361129761s (0.11254130601882935 minutes)
# Estimated 0.11916117849713521 hours to completion.
# Executing mode 19 , irrep M5- for temp 350
# Completed mode 19 (irrep M5-) for temp 350. Process took 8.00454831123352s (0.13340913852055866 minutes)
# Estimated 0.11755350814223242 hours to completion.
# Executing mode 91 , irrep M5- for temp 350
# Completed mode 91 (irrep M5-) for temp 350. Process took 5.916958570480347s (0.09861597617467245 minutes)
# Estimated 0.11580469695918251 hours to completion.
# Executing mode 31 , irrep GM5- for temp 350
# Completed mode 31 (irrep GM5-) for temp 350. Process took 5.049898862838745s (0.08416498104731242 minutes)
# Estimated 0.11400084833234375 hours to completion.
# Executing mode 34 , irrep R2- for temp 350
# Completed mode 34 (irrep R2-) for temp 350. Process took 8.184481143951416s (0.13640801906585692 minutes)
# Estimated 0.11239769488874109 hours to completion.
# Executing mode 35 , irrep R3- for temp 350
# Completed mode 35 (irrep R3-) for temp 350. Process took 7.819965600967407s (0.13033276001612346 minutes)
# Estimated 0.11076729091063887 hours to completion.
# Executing mode 37 , irrep R4- for temp 350
# Completed mode 37 (irrep R4-) for temp 350. Process took 4.880627393722534s (0.08134378989537557 minutes)
# Estimated 0.10895451875196563 hours to completion.
# Executing mode 40 , irrep R5- for temp 350
# Completed mode 40 (irrep R5-) for temp 350. Process took 5.006632328033447s (0.08344387213389079 minutes)
# Estimated 0.10715241846053795 hours to completion.
# Executing mode 46 , irrep X2+ for temp 350
# Completed mode 46 (irrep X2+) for temp 350. Process took 4.934301137924194s (0.08223835229873658 minutes)
# Estimated 0.10534892894961369 hours to completion.
# Executing mode 61 , irrep X3- for temp 350
# Completed mode 61 (irrep X3-) for temp 350. Process took 7.249481439590454s (0.1208246906598409 minutes)
# Estimated 0.10368101345577872 hours to completion.
# Executing mode 64 , irrep X5- for temp 350
# Completed mode 64 (irrep X5-) for temp 350. Process took 5.366116046905518s (0.0894352674484253 minutes)
# Estimated 0.10190502287681064 hours to completion.
# Executing mode 70 , irrep M1+ for temp 350
# Completed mode 70 (irrep M1+) for temp 350. Process took 4.928816080093384s (0.08214693466822307 minutes)
# Estimated 0.10010693474569961 hours to completion.
# Executing mode 73 , irrep M2+ for temp 350
# Completed mode 73 (irrep M2+) for temp 350. Process took 5.875540256500244s (0.09792567094167073 minutes)
# Estimated 0.09836275050767154 hours to completion.
# Executing mode 76 , irrep M3+ for temp 350
# Completed mode 76 (irrep M3+) for temp 350. Process took 7.587855339050293s (0.12646425565083821 minutes)
# Estimated 0.09670961776740583 hours to completion.
# Executing mode 79 , irrep M4+ for temp 350
# Completed mode 79 (irrep M4+) for temp 350. Process took 7.389133930206299s (0.12315223217010499 minutes)
# Estimated 0.09504315654324877 hours to completion.
# Executing mode 82 , irrep M5+ for temp 350
# Completed mode 82 (irrep M5+) for temp 350. Process took 5.7771570682525635s (0.09628595113754272 minutes)
# Estimated 0.0932926825080255 hours to completion.
# Executing mode 0 , irrep nomodes for temp 375
# Completed mode 0 (irrep nomodes) for temp 375. Process took 10.365798711776733s (0.17276331186294555 minutes)
# Estimated 0.09176988101756725 hours to completion.
# Executing mode 1 , irrep GM4- for temp 375
# Completed mode 1 (irrep GM4-) for temp 375. Process took 6.047118425369263s (0.10078530708948771 minutes)
# Estimated 0.09002937346840825 hours to completion.
# Executing mode 25 , irrep GM4- for temp 375
# Completed mode 25 (irrep GM4-) for temp 375. Process took 10.054865837097168s (0.1675810972849528 minutes)
# Estimated 0.08847852567434311 hours to completion.
# Executing mode 28 , irrep GM4- for temp 375
# Completed mode 28 (irrep GM4-) for temp 375. Process took 4.8808863162994385s (0.08134810527165731 minutes)
# Estimated 0.08668068396776706 hours to completion.
# Executing mode 4 , irrep R5+ for temp 375
# Completed mode 4 (irrep R5+) for temp 375. Process took 7.190451145172119s (0.11984085241953532 minutes)
# Estimated 0.0849898615439996 hours to completion.
# Executing mode 7 , irrep X1+ for temp 375
# Completed mode 7 (irrep X1+) for temp 375. Process took 9.432150840759277s (0.15720251401265461 minutes)
# Estimated 0.083395660503207 hours to completion.
# Executing mode 43 , irrep X1+ for temp 375
# Completed mode 43 (irrep X1+) for temp 375. Process took 5.096806764602661s (0.08494677941004435 minutes)
# Estimated 0.08160852522834351 hours to completion.
# Executing mode 10 , irrep X5+ for temp 375
# Completed mode 10 (irrep X5+) for temp 375. Process took 10.104798555374146s (0.16841330925623577 minutes)
# Estimated 0.08003363165004224 hours to completion.
# Executing mode 49 , irrep X5+ for temp 375
# Completed mode 49 (irrep X5+) for temp 375. Process took 8.343443155288696s (0.13905738592147826 minutes)
# Estimated 0.07837873502494463 hours to completion.
# Executing mode 55 , irrep X5+ for temp 375
# Completed mode 55 (irrep X5+) for temp 375. Process took 5.777164459228516s (0.09628607432047526 minutes)
# Estimated 0.07661735279250309 hours to completion.
# Executing mode 16 , irrep M2- for temp 375
# Completed mode 16 (irrep M2-) for temp 375. Process took 7.1869165897369385s (0.11978194316228231 minutes)
# Estimated 0.07491165865959887 hours to completion.
# Executing mode 88 , irrep M2- for temp 375
# Completed mode 88 (irrep M2-) for temp 375. Process took 6.767247676849365s (0.11278746128082276 minutes)
# Estimated 0.07318823805261712 hours to completion.
# Executing mode 19 , irrep M5- for temp 375
# Completed mode 19 (irrep M5-) for temp 375. Process took 7.718661546707153s (0.1286443591117859 minutes)
# Estimated 0.07149876198119161 hours to completion.
# Executing mode 91 , irrep M5- for temp 375
# Completed mode 91 (irrep M5-) for temp 375. Process took 5.7353222370147705s (0.09558870395024617 minutes)
# Estimated 0.0697355036055799 hours to completion.
# Executing mode 31 , irrep GM5- for temp 375
# Completed mode 31 (irrep GM5-) for temp 375. Process took 5.516871213912964s (0.09194785356521606 minutes)
# Estimated 0.06796575059493383 hours to completion.
# Executing mode 34 , irrep R2- for temp 375
# Completed mode 34 (irrep R2-) for temp 375. Process took 8.931864261627197s (0.14886440436045328 minutes)
# Estimated 0.06631268041625614 hours to completion.
# Executing mode 35 , irrep R3- for temp 375
# Completed mode 35 (irrep R3-) for temp 375. Process took 9.736121416091919s (0.16226869026819865 minutes)
# Estimated 0.06468066109698964 hours to completion.
# Executing mode 37 , irrep R4- for temp 375
# Completed mode 37 (irrep R4-) for temp 375. Process took 5.139755725860596s (0.08566259543100993 minutes)
# Estimated 0.06289591614405314 hours to completion.
# Executing mode 40 , irrep R5- for temp 375
# Completed mode 40 (irrep R5-) for temp 375. Process took 5.085215330123901s (0.08475358883539835 minutes)
# Estimated 0.06111175288798605 hours to completion.
# Executing mode 46 , irrep X2+ for temp 375
# Completed mode 46 (irrep X2+) for temp 375. Process took 4.862862586975098s (0.0810477097829183 minutes)
# Estimated 0.05932330953335286 hours to completion.
# Executing mode 61 , irrep X3- for temp 375
# Completed mode 61 (irrep X3-) for temp 375. Process took 8.894574642181396s (0.14824291070302328 minutes)
# Estimated 0.057653836797868174 hours to completion.
# Executing mode 64 , irrep X5- for temp 375
# Completed mode 64 (irrep X5-) for temp 375. Process took 5.128080368041992s (0.0854680061340332 minutes)
# Estimated 0.055874387780285514 hours to completion.
# Executing mode 70 , irrep M1+ for temp 375
# Completed mode 70 (irrep M1+) for temp 375. Process took 5.898927688598633s (0.09831546147664388 minutes)
# Estimated 0.05411790068902904 hours to completion.
# Executing mode 73 , irrep M2+ for temp 375
# Completed mode 73 (irrep M2+) for temp 375. Process took 4.910693168640137s (0.08184488614400227 minutes)
# Estimated 0.05233649305094068 hours to completion.
# Executing mode 76 , irrep M3+ for temp 375
# Completed mode 76 (irrep M3+) for temp 375. Process took 11.44472074508667s (0.1907453457514445 minutes)
# Estimated 0.05072114092387193 hours to completion.
# Executing mode 79 , irrep M4+ for temp 375
# Completed mode 79 (irrep M4+) for temp 375. Process took 10.47927188873291s (0.17465453147888182 minutes)
# Estimated 0.04907285839247466 hours to completion.
# Executing mode 82 , irrep M5+ for temp 375
# Completed mode 82 (irrep M5+) for temp 375. Process took 5.930583238601685s (0.09884305397669474 minutes)
# Estimated 0.04731148815265409 hours to completion.
# Executing mode 0 , irrep nomodes for temp 400
# Completed mode 0 (irrep nomodes) for temp 400. Process took 10.659536838531494s (0.17765894730885823 minutes)
# Estimated 0.04565590722295973 hours to completion.
# Executing mode 1 , irrep GM4- for temp 400
# Completed mode 1 (irrep GM4-) for temp 400. Process took 9.409918546676636s (0.15683197577794392 minutes)
# Estimated 0.04396569835505846 hours to completion.
# Executing mode 25 , irrep GM4- for temp 400
# Completed mode 25 (irrep GM4-) for temp 400. Process took 10.008947849273682s (0.16681579748789468 minutes)
# Estimated 0.04228205283239833 hours to completion.
# Executing mode 28 , irrep GM4- for temp 400
# Completed mode 28 (irrep GM4-) for temp 400. Process took 4.91091775894165s (0.08184862931569417 minutes)
# Estimated 0.04049241955566212 hours to completion.
# Executing mode 4 , irrep R5+ for temp 400
# Completed mode 4 (irrep R5+) for temp 400. Process took 6.786418676376343s (0.11310697793960571 minutes)
# Estimated 0.03874020990629689 hours to completion.
# Executing mode 7 , irrep X1+ for temp 400
# Completed mode 7 (irrep X1+) for temp 400. Process took 9.472874402999878s (0.15788124004999796 minutes)
# Estimated 0.037034682615838865 hours to completion.
# Executing mode 43 , irrep X1+ for temp 400
# Completed mode 43 (irrep X1+) for temp 400. Process took 5.013131380081177s (0.08355218966801961 minutes)
# Estimated 0.03524870818475222 hours to completion.
# Executing mode 10 , irrep X5+ for temp 400
# Completed mode 10 (irrep X5+) for temp 400. Process took 10.243218660354614s (0.17072031100591023 minutes)
# Estimated 0.03354824614612613 hours to completion.
# Executing mode 49 , irrep X5+ for temp 400
# Completed mode 49 (irrep X5+) for temp 400. Process took 8.774777173995972s (0.1462462862332662 minutes)
# Estimated 0.03181885930152985 hours to completion.
# Executing mode 55 , irrep X5+ for temp 400
# Completed mode 55 (irrep X5+) for temp 400. Process took 4.966130018234253s (0.08276883363723755 minutes)
# Estimated 0.030031384490603854 hours to completion.
# Executing mode 16 , irrep M2- for temp 400
# Completed mode 16 (irrep M2-) for temp 400. Process took 8.50005841255188s (0.141667640209198 minutes)
# Estimated 0.028293230088393684 hours to completion.
# Executing mode 88 , irrep M2- for temp 400
# Completed mode 88 (irrep M2-) for temp 400. Process took 8.475632905960083s (0.14126054843266805 minutes)
# Estimated 0.026551064618286633 hours to completion.
# Executing mode 19 , irrep M5- for temp 400
# Completed mode 19 (irrep M5-) for temp 400. Process took 6.848795413970947s (0.11414659023284912 minutes)
# Estimated 0.024786492785407576 hours to completion.
# Executing mode 91 , irrep M5- for temp 400
# Completed mode 91 (irrep M5-) for temp 400. Process took 4.743677616119385s (0.07906129360198974 minutes)
# Estimated 0.02299861457103338 hours to completion.
# Executing mode 31 , irrep GM5- for temp 400
# Completed mode 31 (irrep GM5-) for temp 400. Process took 4.263641595840454s (0.07106069326400757 minutes)
# Estimated 0.021208790220693854 hours to completion.
# Executing mode 34 , irrep R2- for temp 400
# Completed mode 34 (irrep R2-) for temp 400. Process took 8.504552364349365s (0.14174253940582277 minutes)
# Estimated 0.019460640274426518 hours to completion.
# Executing mode 35 , irrep R3- for temp 400
# Completed mode 35 (irrep R3-) for temp 400. Process took 9.107770919799805s (0.15179618199666342 minutes)
# Estimated 0.017713801635131265 hours to completion.
# Executing mode 37 , irrep R4- for temp 400
# Completed mode 37 (irrep R4-) for temp 400. Process took 4.928655624389648s (0.08214426040649414 minutes)
# Estimated 0.01593183438854608 hours to completion.
# Executing mode 40 , irrep R5- for temp 400
# Completed mode 40 (irrep R5-) for temp 400. Process took 4.975457668304443s (0.08292429447174073 minutes)
# Estimated 0.01415257792044968 hours to completion.
# Executing mode 46 , irrep X2+ for temp 400
# Completed mode 46 (irrep X2+) for temp 400. Process took 4.533131122589111s (0.07555218537648518 minutes)
# Estimated 0.012373130436052955 hours to completion.
# Executing mode 61 , irrep X3- for temp 400
# Completed mode 61 (irrep X3-) for temp 400. Process took 7.829943895339966s (0.13049906492233276 minutes)
# Estimated 0.010612625492943659 hours to completion.
# Executing mode 64 , irrep X5- for temp 400
# Completed mode 64 (irrep X5-) for temp 400. Process took 5.392201662063599s (0.08987002770105998 minutes)
# Estimated 0.008839939301145636 hours to completion.
# Executing mode 70 , irrep M1+ for temp 400
# Completed mode 70 (irrep M1+) for temp 400. Process took 4.680745840072632s (0.07801243066787719 minutes)
# Estimated 0.007066559156392806 hours to completion.
# Executing mode 73 , irrep M2+ for temp 400
# Completed mode 73 (irrep M2+) for temp 400. Process took 4.828178882598877s (0.08046964804331462 minutes)
# Estimated 0.005296251444981015 hours to completion.
# Executing mode 76 , irrep M3+ for temp 400
# Completed mode 76 (irrep M3+) for temp 400. Process took 8.561795949935913s (0.14269659916559854 minutes)
# Estimated 0.0035343463855046294 hours to completion.
# Executing mode 79 , irrep M4+ for temp 400
# Completed mode 79 (irrep M4+) for temp 400. Process took 9.58732271194458s (0.159788711865743 minutes)
# Estimated 0.001769733112766629 hours to completion.
# Executing mode 82 , irrep M5+ for temp 400
# Completed mode 82 (irrep M5+) for temp 400. Process took 4.765217542648315s (0.07942029237747192 minutes)
# Estimated 0.0 hours to completion.

# %% [markdown]
# Notice this is a lot quicker than the grouped mode run! It is probably best done prior to executing a grouped mode run overnight.
#
# Creating the HDF5 file and cleaning up also require slightly different functions. This is due to the HDF5 file having an extra level of depth (i.e. it has datasets at irrep/mode/prm vs irrep/prm for grouped mode). These also have the unique_modes argument - they won't work if this is different to what is specified for the execute_single function. Like the execute_single function, this is default set to True.

# %%
struc.create_hdf5_single(temps)

struc.cleanup_single()
# Out:
# Creating zip file...
# ...Zip file written.
# Deleting .txt files...
# ...Clean up complete.

# %% [markdown]
# This is the end of this tutorial - move on to SingleMode_ScF3_analysis for analysis of the data generated here.
