# %% [markdown]
# # Symmetry Adapted PDF Analysis - Running SAPA
#
#
#
#
#
#
#
#
#
# First, import the sapa library

# %%
import sapa as s

# %% [markdown]
# Next, we need to create a SAPA object. This imports all the data from a CIF.

# %%
struc = s.sapa('BaTiO3_iso.cif')

# %% [markdown]
# We can see the list of "methods" the SAPA object has:

# %%
dir(struc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'atom_site_Wyckoff_label',
#  'atom_site_fract_symmform',
#  'atom_site_fract_x',
#  'atom_site_fract_y',
#  'atom_site_fract_z',
#  'atom_site_label',
#  'atom_site_occupancy',
#  'atom_site_symmetry_multiplicity',
#  'atom_site_type_symbol',
#  'cell_angle_alpha',
#  'cell_angle_beta',
#  'cell_angle_gamma',
#  'cell_length_a',
#  'cell_length_b',
#  'cell_length_c',
#  'cell_volume',
#  'cleanup',
#  'constraint_array',
#  'constraints_out',
#  'create_hdf5',
#  'create_hdf5_single',
#  'execute',
#  'execute_occ',
#  'execute_single',
#  'file_check',
#  'get_indices',
#  'idformat',
#  'instrument_pars',
#  'irrep_list',
#  'iso_coordinate_formula',
#  'iso_coordinate_label',
#  'iso_deltacoordinate_ID',
#  'iso_deltacoordinate_label',
#  'iso_deltacoordinate_value',
#  'iso_displacivemode_ID',
#  'iso_displacivemode_label',
#  'iso_displacivemode_number',
#  'iso_displacivemode_value',
#  'iso_displacivemodematrix_col',
#  'iso_displacivemodematrix_row',
#  'iso_displacivemodematrix_value',
#  'iso_displacivemodenorm_ID',
#  'iso_displacivemodenorm_value',
#  'iso_magneticmode_number',
#  'iso_occupancymode_number',
#  'iso_rotationalmode_number',
#  'iso_strain_ID',
#  'iso_strain_label',
#  'iso_strain_value',
#  'iso_strainmode_ID',
#  'iso_strainmode_label',
#  'iso_strainmode_number',
#  'iso_strainmode_value',
#  'iso_strainmodematrix_col',
#  'iso_strainmodematrix_row',
#  'iso_strainmodematrix_value',
#  'iso_strainmodenorm_ID',
#  'iso_strainmodenorm_value',
#  'make_matrices',
#  'make_x_y_z_constrains',
#  'modes',
#  'modes_single',
#  'output',
#  'output_single',
#  'phase',
#  'restart',
#  'space_group.transform_Pp_abc',
#  'space_group_symop_id',
#  'space_group_symop_operation_xyz',
#  'symmetry_Int_Tables_number',
#  'unique_modes',
#  'wd',
#  'write_inp',
#  'write_inp_single']

# %% [markdown]
# A lot of these are variables imported from the CIF itself. For example:

# %%
print(struc.cell_length_a)
print(struc.cell_length_b)
print(struc.cell_length_c)
# Out:
# 8.07084
# 8.07084
# 8.07084

# %% [markdown]
# This gives the lattice parameters of the supercell we chose when we generated the CIF with ISODISTORT.
#
# Other methods operate on the information provided in the CIF. For example:

# %%
struc.irrep_list()
# Out:
# ['GM4-',
#  'R4-',
#  'X3-',
#  'X5-',
#  'M3-',
#  'M5-',
#  'R5+',
#  'X1+',
#  'X5+',
#  'M2-',
#  'GM5-',
#  'R2-',
#  'R3-',
#  'R5-',
#  'X2+',
#  'M1+',
#  'M2+',
#  'M3+',
#  'M4+',
#  'M5+']

# %% [markdown]
# This provides a list of irreps contained within the CIF.

# %% [markdown]
# We are going to use the "write_inp" method to make an input file to perform symmetry adapted PDF analysis. The required arguments takes are (in order):
#
# sample:
# A "sample" string to remind you what you are running. This is often just the material you are analysing. This is repeated in the output files SAPA produces.
#
# filenameformat:
# This is a string to allow Topas to iterate over the data files. This includes any path information - SAPA assumes the data is in the working directory, so you need to specify if it isn't. Your data file names should be in a format to allow for iteration, i.e. they have a consistent naming convention such as "BaTiO3_15K.xy", "BaTiO3_150K.xy". The temperatures here can be iterated over, and to tell Topas that, replace the temperature with ##n## (filenameformat = "BaTiO3_##n##K.xy")
#
# isneutron:
# Set this to True if you are using neutron data, or False for X-ray data. For this example with BaTiO3, we are using neutron data.
#
# qmax:
# The maximum value of Q used to generate the PDF data. For this data, qmax = 40.
#
# dq:
# The Q-space dampening parameter. For this data, dq = 0.033
#
# startx, finishx:
# The r-range to start and end the refinement at. For SAPA, most of the information is contained within the low-r region. For this data, set startx = 1.7 and finishx = 10.0
#
# lattice:
# This is a flag to allow lattice parameters to refine as they should for a given lattice type. This can be "C", "T", "O", "R", "H", "TC" or "M", for cubic, tetragonal, orthorhombic, rhombohedral, hexagonal, triclinic and monoclinic, respectively. For now, use lattice = "C".
#
# There are further optional arguments that can be specified. The relevant ones for today are:
#
# cycles:
# The number of cycles to perform for each irrep. The default is 300, but for time purposes, lets lower this to 100.
#
# filename:
# The default is "batch_modes.inp", but this can be changed. Obviously, it still requires the .inp file extension, whatever the name is.

# %%
struc.write_inp(sample="BaTiO3", filenameformat="BaTiO3_##n##K.xy", isneutron=True, qmax=40.0, dq=0.033, startx=1.7, finishx=10.0, lattice="C", cycles=100)
# Out:
# Creating input file...
# 120
# 120
# ...batch_modes.inp written

# %% [markdown]
# This has printed the number of modes in the input file (120 in this case), and has indicated an input file has been written. This can be viewed using jEdit, and we can go through the components of that input file later, time providing.

# %% [markdown]
# Now, we set the temperatures of our data files. (NB: these don't have to be temperatures, it is simply something to iterate over). This can be specified as a list (as below) if you don't have a regular interval between data points. Often at I15-1, we collect data at regular intervals, so we could use temps = range(start, finish + interval, interval)

# %%
temps = [15, 150, 210, 250, 293, 350, 410, 500]

# %% [markdown]
# And now, we can set the code to be run. For each temperature and irrep, this tells Topas to execute the input file with the correct modes activated.

# %%
struc.execute(temps)
# Out:
# Finding Topas executables...
# Creating Monitoring File...
# Executing...
# Executing irrep GM4- for temp 15
# Completed irrep GM4- for temp 15. Process took 123.49915361404419s (2.0583192269007364 minutes)
# Estimated 5.728988514873716 hours to completion.
# Executing irrep R4- for temp 15
# Completed irrep R4- for temp 15. Process took 127.39775681495667s (2.1232959469159445 minutes)
# Estimated 5.784567657113075 hours to completion.
# Executing irrep X3- for temp 15
# Completed irrep X3- for temp 15. Process took 143.36500883102417s (2.389416813850403 minutes)
# Estimated 6.023445988694827 hours to completion.
# Executing irrep X5- for temp 15
# Completed irrep X5- for temp 15. Process took 155.01531505584717s (2.5835885842641195 minutes)
# Estimated 6.255657390819655 hours to completion.
# Executing irrep M3- for temp 15
# Completed irrep M3- for temp 15. Process took 81.90768074989319s (1.36512801249822 minutes)
# Estimated 5.715730064206654 hours to completion.
# Executing irrep M5- for temp 15
# Completed irrep M5- for temp 15. Process took 228.4366147518158s (3.8072769125302632 minutes)
# Estimated 6.4471614736318585 hours to completion.
# Executing irrep R5+ for temp 15
# Completed irrep R5+ for temp 15. Process took 79.3575050830841s (1.3226250847180685 minutes)
# Estimated 5.999032722976473 hours to completion.
# Executing irrep X1+ for temp 15
# Completed irrep X1+ for temp 15. Process took 156.56377696990967s (2.609396282831828 minutes)
# Estimated 6.086348954836527 hours to completion.
# Executing irrep X5+ for temp 15
# Completed irrep X5+ for temp 15. Process took 287.0847475528717s (4.784745792547862 minutes)
# Estimated 6.785116726800248 hours to completion.
# Executing irrep M2- for temp 15
# Completed irrep M2- for temp 15. Process took 155.2342381477356s (2.58723730246226 minutes)
# Estimated 6.749504556006856 hours to completion.
# Executing irrep GM5- for temp 15
# Completed irrep GM5- for temp 15. Process took 103.72134757041931s (1.7286891261736552 minutes)
# Estimated 6.508296812808874 hours to completion.
# Executing irrep R2- for temp 15
# Completed irrep R2- for temp 15. Process took 56.73109412193298s (0.9455182353655497 minutes)
# Estimated 6.132801419562764 hours to completion.
# Executing irrep R3- for temp 15
# Completed irrep R3- for temp 15. Process took 62.076053857803345s (1.0346008976300558 minutes)
# Estimated 5.830352466534346 hours to completion.
# Executing irrep R5- for temp 15
# Completed irrep R5- for temp 15. Process took 85.84323382377625s (1.430720563729604 minutes)
# Estimated 5.641269110110071 hours to completion.
# Executing irrep X2+ for temp 15
# Completed irrep X2+ for temp 15. Process took 121.02439141273499s (2.01707319021225 minutes)
# Estimated 5.573897435347239 hours to completion.
# Executing irrep M1+ for temp 15
# Completed irrep M1+ for temp 15. Process took 81.31969213485718s (1.3553282022476196 minutes)
# Estimated 5.405968694355753 hours to completion.
# Executing irrep M2+ for temp 15
# Completed irrep M2+ for temp 15. Process took 91.41164040565491s (1.5235273400942484 minutes)
# Estimated 5.280038838000858 hours to completion.
# Executing irrep M3+ for temp 15
# Completed irrep M3+ for temp 15. Process took 96.87722849845886s (1.6146204749743143 minutes)
# Estimated 5.177931665270417 hours to completion.
# Executing irrep M4+ for temp 15
# Completed irrep M4+ for temp 15. Process took 65.18590044975281s (1.0864316741625468 minutes)
# Estimated 5.014704745572213 hours to completion.
# Executing irrep M5+ for temp 15
# Completed irrep M5+ for temp 15. Process took 131.90790343284607s (2.198465057214101 minutes)
# Estimated 5.0031405822965835 hours to completion.
# Executing irrep nomodes for temp 15
# Completed irrep nomodes for temp 15. Process took 51.86720299720764s (0.864453383286794 minutes)
# Estimated 4.833553445537885 hours to completion.
# Executing irrep GM4- for temp 150
# Completed irrep GM4- for temp 150. Process took 143.3575565814972s (2.38929260969162 minutes)
# Estimated 4.846730003248561 hours to completion.
# Executing irrep R4- for temp 150
# Completed irrep R4- for temp 150. Process took 122.12102174758911s (2.0353503624598184 minutes)
# Estimated 4.818108446471357 hours to completion.
# Executing irrep X3- for temp 150
# Completed irrep X3- for temp 150. Process took 129.07446765899658s (2.1512411276499432 minutes)
# Estimated 4.800634220441182 hours to completion.
# Executing irrep X5- for temp 150
# Completed irrep X5- for temp 150. Process took 181.09024906158447s (3.0181708176930746 minutes)
# Estimated 4.864336908107333 hours to completion.
# Executing irrep M3- for temp 150
# Completed irrep M3- for temp 150. Process took 79.28421998023987s (1.3214036663373312 minutes)
# Estimated 4.764820621640255 hours to completion.
# Executing irrep M5- for temp 150
# Completed irrep M5- for temp 150. Process took 226.6482219696045s (3.777470366160075 minutes)
# Estimated 4.884813317715386 hours to completion.
# Executing irrep R5+ for temp 150
# Completed irrep R5+ for temp 150. Process took 82.61562967300415s (1.3769271612167358 minutes)
# Estimated 4.7916928513182535 hours to completion.
# Executing irrep X1+ for temp 150
# Completed irrep X1+ for temp 150. Process took 132.37401509284973s (2.2062335848808288 minutes)
# Estimated 4.769661002469702 hours to completion.
# Executing irrep X5+ for temp 150
# Completed irrep X5+ for temp 150. Process took 278.3451929092407s (4.639086548487345 minutes)
# Estimated 4.933165300104354 hours to completion.
# Executing irrep M2- for temp 150
# Completed irrep M2- for temp 150. Process took 131.3465917110443s (2.1891098618507385 minutes)
# Estimated 4.900677396189355 hours to completion.
# Executing irrep GM5- for temp 150
# Completed irrep GM5- for temp 150. Process took 107.4123969078064s (1.7902066151301066 minutes)
# Estimated 4.839684016853571 hours to completion.
# Executing irrep R2- for temp 150
# Completed irrep R2- for temp 150. Process took 59.05481958389282s (0.9842469930648804 minutes)
# Estimated 4.72562712403861 hours to completion.
# Executing irrep R3- for temp 150
# Completed irrep R3- for temp 150. Process took 65.83013725280762s (1.0971689542134604 minutes)
# Estimated 4.624731935118538 hours to completion.
# Executing irrep R5- for temp 150
# Completed irrep R5- for temp 150. Process took 80.29213452339172s (1.3382022420565287 minutes)
# Estimated 4.543822704315185 hours to completion.
# Executing irrep X2+ for temp 150
# Completed irrep X2+ for temp 150. Process took 96.78109741210938s (1.6130182902018229 minutes)
# Estimated 4.482963668681957 hours to completion.
# Executing irrep M1+ for temp 150
# Completed irrep M1+ for temp 150. Process took 92.52682828903198s (1.5421138048171996 minutes)
# Estimated 4.419757137602872 hours to completion.
# Executing irrep M2+ for temp 150
# Completed irrep M2+ for temp 150. Process took 91.08375430107117s (1.5180625716845195 minutes)
# Estimated 4.35715319240651 hours to completion.
# Executing irrep M3+ for temp 150
# Completed irrep M3+ for temp 150. Process took 84.43579387664795s (1.4072632312774658 minutes)
# Estimated 4.290354047794628 hours to completion.
# Executing irrep M4+ for temp 150
# Completed irrep M4+ for temp 150. Process took 69.51742768287659s (1.1586237947146099 minutes)
# Estimated 4.212461371103922 hours to completion.
# Executing irrep M5+ for temp 150
# Completed irrep M5+ for temp 150. Process took 126.17971277236938s (2.102995212872823 minutes)
# Estimated 4.186180500803278 hours to completion.
# Executing irrep nomodes for temp 150
# Completed irrep nomodes for temp 150. Process took 54.30039620399475s (0.9050066033999126 minutes)
# Estimated 4.099582626223564 hours to completion.
# Executing irrep GM4- for temp 210
# Completed irrep GM4- for temp 210. Process took 142.90657305717468s (2.3817762176195783 minutes)
# Estimated 4.087859919674945 hours to completion.
# Executing irrep R4- for temp 210
# Completed irrep R4- for temp 210. Process took 121.45964074134827s (2.0243273456891377 minutes)
# Estimated 4.058076422304818 hours to completion.
# Executing irrep X3- for temp 210
# Completed irrep X3- for temp 210. Process took 113.83698415756226s (1.8972830692927043 minutes)
# Estimated 4.022329561599979 hours to completion.
# Executing irrep X5- for temp 210
# Completed irrep X5- for temp 210. Process took 183.41838240623474s (3.0569730401039124 minutes)
# Estimated 4.038023727556357 hours to completion.
# Executing irrep M3- for temp 210
# Completed irrep M3- for temp 210. Process took 80.19543361663818s (1.3365905602773032 minutes)
# Estimated 3.977064160869477 hours to completion.
# Executing irrep M5- for temp 210
# Completed irrep M5- for temp 210. Process took 239.31595277786255s (3.9885992129643757 minutes)
# Estimated 4.028216748767429 hours to completion.
# Executing irrep R5+ for temp 210
# Completed irrep R5+ for temp 210. Process took 97.893479347229s (1.6315579891204834 minutes)
# Estimated 3.979164093600379 hours to completion.
# Executing irrep X1+ for temp 210
# Completed irrep X1+ for temp 210. Process took 143.6057412624359s (2.3934290210405984 minutes)
# Estimated 3.9609527665694557 hours to completion.
# Executing irrep X5+ for temp 210
# Completed irrep X5+ for temp 210. Process took 252.71919226646423s (4.211986537774404 minutes)
# Estimated 4.011424358054703 hours to completion.
# Executing irrep M2- for temp 210
# Completed irrep M2- for temp 210. Process took 154.88658952713013s (2.5814431587855022 minutes)
# Estimated 3.996631976457743 hours to completion.
# Executing irrep GM5- for temp 210
# Completed irrep GM5- for temp 210. Process took 132.67611694335938s (2.2112686157226564 minutes)
# Estimated 3.9673874335468944 hours to completion.
# Executing irrep R2- for temp 210
# Completed irrep R2- for temp 210. Process took 60.14456057548523s (1.0024093429247538 minutes)
# Estimated 3.895327103851754 hours to completion.
# Executing irrep R3- for temp 210
# Completed irrep R3- for temp 210. Process took 61.2860107421875s (1.0214335123697917 minutes)
# Estimated 3.825931062648995 hours to completion.
# Executing irrep R5- for temp 210
# Completed irrep R5- for temp 210. Process took 77.58037400245667s (1.2930062333742778 minutes)
# Estimated 3.767457879384359 hours to completion.
# Executing irrep X2+ for temp 210
# Completed irrep X2+ for temp 210. Process took 90.90164613723755s (1.515027435620626 minutes)
# Estimated 3.71748619406544 hours to completion.
# Executing irrep M1+ for temp 210
# Completed irrep M1+ for temp 210. Process took 89.2735333442688s (1.48789222240448 minutes)
# Estimated 3.66750924262964 hours to completion.
# Executing irrep M2+ for temp 210
# Completed irrep M2+ for temp 210. Process took 76.94971680641174s (1.2824952801068623 minutes)
# Estimated 3.6120614389387677 hours to completion.
# Executing irrep M3+ for temp 210
# Completed irrep M3+ for temp 210. Process took 73.07900428771973s (1.2179834047953289 minutes)
# Estimated 3.555814041733742 hours to completion.
# Executing irrep M4+ for temp 210
# Completed irrep M4+ for temp 210. Process took 71.5665214061737s (1.1927753567695618 minutes)
# Estimated 3.5000083001888944 hours to completion.
# Executing irrep M5+ for temp 210
# Completed irrep M5+ for temp 210. Process took 130.68941593170166s (2.178156932195028 minutes)
# Estimated 3.4734395439308603 hours to completion.
# Executing irrep nomodes for temp 210
# Completed irrep nomodes for temp 210. Process took 54.71494007110596s (0.9119156678517659 minutes)
# Estimated 3.411388407813178 hours to completion.
# Executing irrep GM4- for temp 250
# Completed irrep GM4- for temp 250. Process took 141.6958270072937s (2.361597116788228 minutes)
# Estimated 3.390063619530863 hours to completion.
# Executing irrep R4- for temp 250
# Completed irrep R4- for temp 250. Process took 121.12138247489929s (2.018689707914988 minutes)
# Estimated 3.3591276305424858 hours to completion.
# Executing irrep X3- for temp 250
# Completed irrep X3- for temp 250. Process took 120.52456736564636s (2.0087427894274392 minutes)
# Estimated 3.327853347002858 hours to completion.
# Executing irrep X5- for temp 250
# Completed irrep X5- for temp 250. Process took 166.86897349357605s (2.7811495582262675 minutes)
# Estimated 3.3159194893574044 hours to completion.
# Executing irrep M3- for temp 250
# Completed irrep M3- for temp 250. Process took 77.16603636741638s (1.2861006061236064 minutes)
# Estimated 3.2663299622488955 hours to completion.
# Executing irrep M5- for temp 250
# Completed irrep M5- for temp 250. Process took 247.38969683647156s (4.123161613941193 minutes)
# Estimated 3.2853992713275164 hours to completion.
# Executing irrep R5+ for temp 250
# Completed irrep R5+ for temp 250. Process took 87.8519606590271s (1.4641993443171184 minutes)
# Estimated 3.239917879753643 hours to completion.
# Executing irrep X1+ for temp 250
# Completed irrep X1+ for temp 250. Process took 142.72745037078857s (2.378790839513143 minutes)
# Estimated 3.215855442014099 hours to completion.
# Executing irrep X5+ for temp 250
# Completed irrep X5+ for temp 250. Process took 241.03869032859802s (4.017311505476633 minutes)
# Estimated 3.2277716836222896 hours to completion.
# Executing irrep M2- for temp 250
# Completed irrep M2- for temp 250. Process took 145.97692322731018s (2.43294872045517 minutes)
# Estimated 3.2031630310339105 hours to completion.
# Executing irrep GM5- for temp 250
# Completed irrep GM5- for temp 250. Process took 92.42989563941956s (1.5404982606569926 minutes)
# Estimated 3.159229332870907 hours to completion.
# Executing irrep R2- for temp 250
# Completed irrep R2- for temp 250. Process took 56.653181076049805s (0.9442196846008301 minutes)
# Estimated 3.103459443526798 hours to completion.
# Executing irrep R3- for temp 250
# Completed irrep R3- for temp 250. Process took 70.63601064682007s (1.1772668441136678 minutes)
# Estimated 3.0534448800658622 hours to completion.
# Executing irrep R5- for temp 250
# Completed irrep R5- for temp 250. Process took 77.32705473899841s (1.2887842456499736 minutes)
# Estimated 3.0064163117276297 hours to completion.
# Executing irrep X2+ for temp 250
# Completed irrep X2+ for temp 250. Process took 94.23083353042603s (1.5705138921737671 minutes)
# Estimated 2.965460719435643 hours to completion.
# Executing irrep M1+ for temp 250
# Completed irrep M1+ for temp 250. Process took 74.65090441703796s (1.244181740283966 minutes)
# Estimated 2.918751979838276 hours to completion.
# Executing irrep M2+ for temp 250
# Completed irrep M2+ for temp 250. Process took 87.18486309051514s (1.4530810515085857 minutes)
# Estimated 2.876522370378176 hours to completion.
# Executing irrep M3+ for temp 250
# Completed irrep M3+ for temp 250. Process took 70.22237229347229s (1.1703728715578714 minutes)
# Estimated 2.8296766661395747 hours to completion.
# Executing irrep M4+ for temp 250
# Completed irrep M4+ for temp 250. Process took 75.95002913475037s (1.265833818912506 minutes)
# Estimated 2.785166405038782 hours to completion.
# Executing irrep M5+ for temp 250
# Completed irrep M5+ for temp 250. Process took 126.09368824958801s (2.101561470826467 minutes)
# Estimated 2.755484741148221 hours to completion.
# Executing irrep nomodes for temp 250
# Completed irrep nomodes for temp 250. Process took 53.91534948348999s (0.8985891580581665 minutes)
# Estimated 2.7056262920300167 hours to completion.
# Executing irrep GM4- for temp 293
# Completed irrep GM4- for temp 293. Process took 151.30679202079773s (2.5217798670132954 minutes)
# Estimated 2.683005228092468 hours to completion.
# Executing irrep R4- for temp 293
# Completed irrep R4- for temp 293. Process took 122.19457697868347s (2.036576282978058 minutes)
# Estimated 2.652222201761041 hours to completion.
# Executing irrep X3- for temp 293
# Completed irrep X3- for temp 293. Process took 106.3209490776062s (1.7720158179601033 minutes)
# Estimated 2.6172612851858137 hours to completion.
# Executing irrep X5- for temp 293
# Completed irrep X5- for temp 293. Process took 174.00564789772034s (2.900094131628672 minutes)
# Estimated 2.5995158124451687 hours to completion.
# Executing irrep M3- for temp 293
# Completed irrep M3- for temp 293. Process took 78.47712922096252s (1.3079521536827088 minutes)
# Estimated 2.557528776447574 hours to completion.
# Executing irrep M5- for temp 293
# Completed irrep M5- for temp 293. Process took 242.53890705108643s (4.042315117518107 minutes)
# Estimated 2.5554867128928502 hours to completion.
# Executing irrep R5+ for temp 293
# Completed irrep R5+ for temp 293. Process took 78.89850401878357s (1.3149750669797262 minutes)
# Estimated 2.5135463404553566 hours to completion.
# Executing irrep X1+ for temp 293
# Completed irrep X1+ for temp 293. Process took 137.60038232803345s (2.293339705467224 minutes)
# Estimated 2.485511512779383 hours to completion.
# Executing irrep X5+ for temp 293
# Completed irrep X5+ for temp 293. Process took 242.78087949752808s (4.046347991625468 minutes)
# Estimated 2.480819538395892 hours to completion.
# Executing irrep M2- for temp 293
# Completed irrep M2- for temp 293. Process took 167.13168692588806s (2.7855281154314677 minutes)
# Estimated 2.458249845945807 hours to completion.
# Executing irrep GM5- for temp 293
# Completed irrep GM5- for temp 293. Process took 143.776029586792s (2.3962671597798666 minutes)
# Estimated 2.430192654741438 hours to completion.
# Executing irrep R2- for temp 293
# Completed irrep R2- for temp 293. Process took 53.23825240135193s (0.8873042066891988 minutes)
# Estimated 2.3830259142319363 hours to completion.
# Executing irrep R3- for temp 293
# Completed irrep R3- for temp 293. Process took 65.23947286605835s (1.0873245477676392 minutes)
# Estimated 2.33896687899122 hours to completion.
# Executing irrep R5- for temp 293
# Completed irrep R5- for temp 293. Process took 72.86855101585388s (1.2144758502642314 minutes)
# Estimated 2.2969508754355568 hours to completion.
# Executing irrep X2+ for temp 293
# Completed irrep X2+ for temp 293. Process took 82.56987977027893s (1.3761646628379822 minutes)
# Estimated 2.2572529689832166 hours to completion.
# Executing irrep M1+ for temp 293
# Completed irrep M1+ for temp 293. Process took 69.98781275749207s (1.1664635459582011 minutes)
# Estimated 2.2155136864476734 hours to completion.
# Executing irrep M2+ for temp 293
# Completed irrep M2+ for temp 293. Process took 84.06456923484802s (1.4010761539141336 minutes)
# Estimated 2.1768098546621957 hours to completion.
# Executing irrep M3+ for temp 293
# Completed irrep M3+ for temp 293. Process took 69.3028974533081s (1.1550482908884685 minutes)
# Estimated 2.135753811854942 hours to completion.
# Executing irrep M4+ for temp 293
# Completed irrep M4+ for temp 293. Process took 81.9887797832489s (1.3664796630541483 minutes)
# Estimated 2.097344964475822 hours to completion.
# Executing irrep M5+ for temp 293
# Completed irrep M5+ for temp 293. Process took 115.01968288421631s (1.9169947147369384 minutes)
# Estimated 2.0648830827484783 hours to completion.
# Executing irrep nomodes for temp 293
# Completed irrep nomodes for temp 293. Process took 56.79407048225403s (0.9465678413709004 minutes)
# Estimated 2.0227266840934752 hours to completion.
# Executing irrep GM4- for temp 350
# Completed irrep GM4- for temp 350. Process took 176.4551956653595s (2.9409199277559916 minutes)
# Estimated 2.0005098234120156 hours to completion.
# Executing irrep R4- for temp 350
# Completed irrep R4- for temp 350. Process took 106.34340643882751s (1.772390107313792 minutes)
# Estimated 1.9666892032880774 hours to completion.
# Executing irrep X3- for temp 350
# Completed irrep X3- for temp 350. Process took 147.37770295143127s (2.4562950491905213 minutes)
# Estimated 1.9392803101259986 hours to completion.
# Executing irrep X5- for temp 350
# Completed irrep X5- for temp 350. Process took 170.98337483406067s (2.849722913901011 minutes)
# Estimated 1.9151724446548963 hours to completion.
# Executing irrep M3- for temp 350
# Completed irrep M3- for temp 350. Process took 74.58354949951172s (1.2430591583251953 minutes)
# Estimated 1.8765201852755111 hours to completion.
# Executing irrep M5- for temp 350
# Completed irrep M5- for temp 350. Process took 226.25004172325134s (3.7708340287208557 minutes)
# Estimated 1.859825181214659 hours to completion.
# Executing irrep R5+ for temp 350
# Completed irrep R5+ for temp 350. Process took 71.51282262802124s (1.1918803771336874 minutes)
# Estimated 1.8208147497640716 hours to completion.
# Executing irrep X1+ for temp 350
# Completed irrep X1+ for temp 350. Process took 139.0510609149933s (2.317517681916555 minutes)
# Estimated 1.7912744573670034 hours to completion.
# Executing irrep X5+ for temp 350
# Completed irrep X5+ for temp 350. Process took 232.07551527023315s (3.867925254503886 minutes)
# Estimated 1.7738148387482293 hours to completion.
# Executing irrep M2- for temp 350
# Completed irrep M2- for temp 350. Process took 153.95167016983032s (2.5658611694971722 minutes)
# Estimated 1.745536366103352 hours to completion.
# Executing irrep GM5- for temp 350
# Completed irrep GM5- for temp 350. Process took 183.74584984779358s (3.0624308307965595 minutes)
# Estimated 1.7207181401202507 hours to completion.
# Executing irrep R2- for temp 350
# Completed irrep R2- for temp 350. Process took 53.7036988735199s (0.8950616478919983 minutes)
# Estimated 1.679705825408979 hours to completion.
# Executing irrep R3- for temp 350
# Completed irrep R3- for temp 350. Process took 60.83889603614807s (1.0139816006024678 minutes)
# Estimated 1.639975622576958 hours to completion.
# Executing irrep R5- for temp 350
# Completed irrep R5- for temp 350. Process took 79.10753536224365s (1.3184589227040608 minutes)
# Estimated 1.6027186760364793 hours to completion.
# Executing irrep X2+ for temp 350
# Completed irrep X2+ for temp 350. Process took 92.91472911834717s (1.5485788186391194 minutes)
# Estimated 1.5672505726549362 hours to completion.
# Executing irrep M1+ for temp 350
# Completed irrep M1+ for temp 350. Process took 70.04421806335449s (1.1674036343892416 minutes)
# Estimated 1.5294744501423683 hours to completion.
# Executing irrep M2+ for temp 350
# Completed irrep M2+ for temp 350. Process took 79.13894581794739s (1.318982430299123 minutes)
# Estimated 1.4929511899309733 hours to completion.
# Executing irrep M3+ for temp 350
# Completed irrep M3+ for temp 350. Process took 66.60872912406921s (1.1101454854011537 minutes)
# Estimated 1.4553909600507922 hours to completion.
# Executing irrep M4+ for temp 350
# Completed irrep M4+ for temp 350. Process took 76.41615676879883s (1.2736026128133138 minutes)
# Estimated 1.4191047960605245 hours to completion.
# Executing irrep M5+ for temp 350
# Completed irrep M5+ for temp 350. Process took 118.07323956489563s (1.967887326081594 minutes)
# Estimated 1.387040149020089 hours to completion.
# Executing irrep nomodes for temp 350
# Completed irrep nomodes for temp 350. Process took 53.97783398628235s (0.8996305664380392 minutes)
# Estimated 1.3490290997425716 hours to completion.
# Executing irrep GM4- for temp 410
# Completed irrep GM4- for temp 410. Process took 180.94313097000122s (3.0157188495000202 minutes)
# Estimated 1.3227663030091443 hours to completion.
# Executing irrep R4- for temp 410
# Completed irrep R4- for temp 410. Process took 111.24123620986938s (1.854020603497823 minutes)
# Estimated 1.2900780073263578 hours to completion.
# Executing irrep X3- for temp 410
# Completed irrep X3- for temp 410. Process took 99.68540501594543s (1.661423416932424 minutes)
# Estimated 1.2564469808940741 hours to completion.
# Executing irrep X5- for temp 410
# Completed irrep X5- for temp 410. Process took 157.57273054122925s (2.626212175687154 minutes)
# Estimated 1.2276076017913657 hours to completion.
# Executing irrep M3- for temp 410
# Completed irrep M3- for temp 410. Process took 81.39355278015137s (1.3565592130025228 minutes)
# Estimated 1.1925635333148172 hours to completion.
# Executing irrep M5- for temp 410
# Completed irrep M5- for temp 410. Process took 222.02257418632507s (3.700376236438751 minutes)
# Estimated 1.1683615838578254 hours to completion.
# Executing irrep R5+ for temp 410
# Completed irrep R5+ for temp 410. Process took 76.63495993614197s (1.2772493322690328 minutes)
# Estimated 1.1329684113201341 hours to completion.
# Executing irrep X1+ for temp 410
# Completed irrep X1+ for temp 410. Process took 134.99734616279602s (2.2499557693799335 minutes)
# Estimated 1.1018992065562934 hours to completion.
# Executing irrep X5+ for temp 410
# Completed irrep X5+ for temp 410. Process took 215.0078239440918s (3.58346373240153 minutes)
# Estimated 1.0761675518927751 hours to completion.
# Executing irrep M2- for temp 410
# Completed irrep M2- for temp 410. Process took 120.59715700149536s (2.0099526166915895 minutes)
# Estimated 1.0437653721547595 hours to completion.
# Executing irrep GM5- for temp 410
# Completed irrep GM5- for temp 410. Process took 216.07982325553894s (3.6013303875923155 minutes)
# Estimated 1.0173487237103083 hours to completion.
# Executing irrep R2- for temp 410
# Completed irrep R2- for temp 410. Process took 50.28351593017578s (0.838058598836263 minutes)
# Estimated 0.9804331843691748 hours to completion.
# Executing irrep R3- for temp 410
# Completed irrep R3- for temp 410. Process took 61.76195788383484s (1.0293659647305806 minutes)
# Estimated 0.9445130480417341 hours to completion.
# Executing irrep R5- for temp 410
# Completed irrep R5- for temp 410. Process took 80.98551106452942s (1.349758517742157 minutes)
# Estimated 0.9099289445612166 hours to completion.
# Executing irrep X2+ for temp 410
# Completed irrep X2+ for temp 410. Process took 84.12205076217651s (1.4020341793696085 minutes)
# Estimated 0.8756831411097912 hours to completion.
# Executing irrep M1+ for temp 410
# Completed irrep M1+ for temp 410. Process took 70.18018126487732s (1.1696696877479553 minutes)
# Estimated 0.840881463394665 hours to completion.
# Executing irrep M2+ for temp 410
# Completed irrep M2+ for temp 410. Process took 82.9945056438446s (1.3832417607307435 minutes)
# Estimated 0.8069161684038848 hours to completion.
# Executing irrep M3+ for temp 410
# Completed irrep M3+ for temp 410. Process took 59.146318197250366s (0.9857719699541728 minutes)
# Estimated 0.7719983360171319 hours to completion.
# Executing irrep M4+ for temp 410
# Completed irrep M4+ for temp 410. Process took 74.34636664390564s (1.2391061107317607 minutes)
# Estimated 0.7380052485941013 hours to completion.
# Executing irrep M5+ for temp 410
# Completed irrep M5+ for temp 410. Process took 123.29006767272949s (2.0548344612121583 minutes)
# Estimated 0.7062435518080422 hours to completion.
# Executing irrep nomodes for temp 410
# Completed irrep nomodes for temp 410. Process took 56.43385696411133s (0.9405642827351888 minutes)
# Estimated 0.6717950138591585 hours to completion.
# Executing irrep GM4- for temp 500
# Completed irrep GM4- for temp 500. Process took 196.0878083705902s (3.2681301395098368 minutes)
# Estimated 0.6428424233341361 hours to completion.
# Executing irrep R4- for temp 500
# Completed irrep R4- for temp 500. Process took 108.18423175811768s (1.8030705293019613 minutes)
# Estimated 0.6104336715104595 hours to completion.
# Executing irrep X3- for temp 500
# Completed irrep X3- for temp 500. Process took 93.91807436943054s (1.565301239490509 minutes)
# Estimated 0.5775808154582976 hours to completion.
# Executing irrep X5- for temp 500
# Completed irrep X5- for temp 500. Process took 155.37113785743713s (2.589518964290619 minutes)
# Estimated 0.5467393767978446 hours to completion.
# Executing irrep M3- for temp 500
# Completed irrep M3- for temp 500. Process took 84.2361011505127s (1.4039350191752116 minutes)
# Estimated 0.5136558977414293 hours to completion.
# Executing irrep M5- for temp 500
# Completed irrep M5- for temp 500. Process took 217.50206470489502s (3.6250344117482505 minutes)
# Estimated 0.484328261641116 hours to completion.
# Executing irrep R5+ for temp 500
# Completed irrep R5+ for temp 500. Process took 69.77715849876404s (1.1629526416460674 minutes)
# Estimated 0.4508664375242561 hours to completion.
# Executing irrep X1+ for temp 500
# Completed irrep X1+ for temp 500. Process took 137.31262588500977s (2.288543764750163 minutes)
# Estimated 0.41915968848385693 hours to completion.
# Executing irrep X5+ for temp 500
# Completed irrep X5+ for temp 500. Process took 205.81561756134033s (3.4302602926890056 minutes)
# Estimated 0.38883417028647205 hours to completion.
# Executing irrep M2- for temp 500
# Completed irrep M2- for temp 500. Process took 118.08935880661011s (1.9681559801101685 minutes)
# Estimated 0.3564593308746435 hours to completion.
# Executing irrep GM5- for temp 500
# Completed irrep GM5- for temp 500. Process took 219.49239230155945s (3.658206538359324 minutes)
# Estimated 0.325861830529449 hours to completion.
# Executing irrep R2- for temp 500
# Completed irrep R2- for temp 500. Process took 49.93883967399597s (0.8323139945665995 minutes)
# Estimated 0.29221634843064553 hours to completion.
# Executing irrep R3- for temp 500
# Completed irrep R3- for temp 500. Process took 63.24650001525879s (1.0541083335876464 minutes)
# Estimated 0.25900286472505996 hours to completion.
# Executing irrep R5- for temp 500
# Completed irrep R5- for temp 500. Process took 80.02671813964844s (1.3337786356608072 minutes)
# Estimated 0.22618638862734258 hours to completion.
# Executing irrep X2+ for temp 500
# Completed irrep X2+ for temp 500. Process took 92.49272227287292s (1.5415453712145488 minutes)
# Estimated 0.1936288652326835 hours to completion.
# Executing irrep M1+ for temp 500
# Completed irrep M1+ for temp 500. Process took 74.66382217407227s (1.2443970362345378 minutes)
# Estimated 0.16100365987381482 hours to completion.
# Executing irrep M2+ for temp 500
# Completed irrep M2+ for temp 500. Process took 85.89734601974487s (1.4316224336624146 minutes)
# Estimated 0.1285995045312375 hours to completion.
# Executing irrep M3+ for temp 500
# Completed irrep M3+ for temp 500. Process took 61.549800872802734s (1.0258300145467123 minutes)
# Estimated 0.09617594277617908 hours to completion.
# Executing irrep M4+ for temp 500
# Completed irrep M4+ for temp 500. Process took 68.63700652122498s (1.143950108687083 minutes)
# Estimated 0.06396075527511608 hours to completion.
# Executing irrep M5+ for temp 500
# Completed irrep M5+ for temp 500. Process took 116.35514855384827s (1.9392524758974712 minutes)
# Estimated 0.03198241654151452 hours to completion.
# Executing irrep nomodes for temp 500
# Completed irrep nomodes for temp 500. Process took 52.59009051322937s (0.8765015085538228 minutes)
# Estimated 0.0 hours to completion.

# %% [markdown]
# Occasionally, things can interrupt the refinement process, or cause it to hang (e.g. locking your computer). The execute script writes a file to keep track of the temperature and irrep combinations it has and hasn't ran so far, and this can be used to restart the refinement.

# %%
#struc.restart()

# %% [markdown]
# ## Part 2 - Post Execution

# %% [markdown]
# Sometimes something can go wrong with an individual irrep/temp combo, but not interrupt the overall SAPA run. An indicator of this is that the ycalc and yobs files for these runs haven't been generated. Missing files causes problems with the HDF5 file creation. The following script checks that all the expected files are there, and if any are found to be missing, it re-runs them.

# %%
struc.file_check(temps, cycles=100, verbose=False) #re-run a couple times to make sure
# Out:
# Files checked, found no issues!

# %% [markdown]
# SAPA generates a large amount of files, which can be quite cumbersome to deal with. To make dealing with SAPA data more straightforward, we place all the data in these files into a structured file format (HDF5). The file is structured in the same way for every SAPA run, meaning analysis is more repeatable.

# %%
struc.create_hdf5(temps)

# %% [markdown]
# We are still left with the large number of files however. The following script removes them and (optionally) compresses them into an archive.

# %%
struc.cleanup() # optionally set create_zip = False
# Out:
# Creating zip file...
# ...Zip file written.
# Deleting .txt files...
# ...Clean up complete.
