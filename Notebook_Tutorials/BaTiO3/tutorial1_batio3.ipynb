# %% [markdown]
# # Symmetry Adapted PDF Analysis - Running SAPA
#
#
#
#
#
#
#
#
#
# First, import the sapa library

# %%
import sys
sys.path.append('..')

# %%
import sapa as s

# %% [markdown]
# Next, we need to create a SAPA object. This imports all the data from a CIF.

# %%
struc = s.sapa('BaTiO3_iso.cif')

# %% [markdown]
# We can see the list of "methods" the SAPA object has:

# %%
dir(struc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'atom_site_Wyckoff_label',
#  'atom_site_fract_symmform',
#  'atom_site_fract_x',
#  'atom_site_fract_y',
#  'atom_site_fract_z',
#  'atom_site_label',
#  'atom_site_occupancy',
#  'atom_site_symmetry_multiplicity',
#  'atom_site_type_symbol',
#  'cell_angle_alpha',
#  'cell_angle_beta',
#  'cell_angle_gamma',
#  'cell_length_a',
#  'cell_length_b',
#  'cell_length_c',
#  'cell_volume',
#  'cleanup',
#  'cleanup_single',
#  'constraint_array',
#  'constraints_out',
#  'create_hdf5',
#  'create_hdf5_single',
#  'execute',
#  'execute_occ',
#  'execute_old',
#  'execute_single',
#  'file_check',
#  'get_indices',
#  'idformat',
#  'instrument_pars',
#  'irrep_list',
#  'iso_coordinate_formula',
#  'iso_coordinate_label',
#  'iso_deltacoordinate_ID',
#  'iso_deltacoordinate_label',
#  'iso_deltacoordinate_value',
#  'iso_displacivemode_ID',
#  'iso_displacivemode_label',
#  'iso_displacivemode_number',
#  'iso_displacivemode_value',
#  'iso_displacivemodematrix_col',
#  'iso_displacivemodematrix_row',
#  'iso_displacivemodematrix_value',
#  'iso_displacivemodenorm_ID',
#  'iso_displacivemodenorm_value',
#  'iso_magneticmode_number',
#  'iso_occupancymode_number',
#  'iso_rotationalmode_number',
#  'iso_strain_ID',
#  'iso_strain_label',
#  'iso_strain_value',
#  'iso_strainmode_ID',
#  'iso_strainmode_label',
#  'iso_strainmode_number',
#  'iso_strainmode_value',
#  'iso_strainmodematrix_col',
#  'iso_strainmodematrix_row',
#  'iso_strainmodematrix_value',
#  'iso_strainmodenorm_ID',
#  'iso_strainmodenorm_value',
#  'make_matrices',
#  'make_x_y_z_constrains',
#  'modes',
#  'modes_single',
#  'output',
#  'output_single',
#  'phase',
#  'restart',
#  'space_group.transform_Pp_abc',
#  'space_group_symop_id',
#  'space_group_symop_operation_xyz',
#  'symmetry_Int_Tables_number',
#  'unique_modes',
#  'wd',
#  'write_inp',
#  'write_inp_single']

# %% [markdown]
# A lot of these are variables imported from the CIF itself. For example:

# %%
print(struc.cell_length_a)
print(struc.cell_length_b)
print(struc.cell_length_c)
# Out:
# 8.07084
# 8.07084
# 8.07084

# %% [markdown]
# This gives the lattice parameters of the supercell we chose when we generated the CIF with ISODISTORT.
#
# Other methods operate on the information provided in the CIF. For example:

# %%
struc.irrep_list()
# Out:
# ['GM4-',
#  'R4-',
#  'X3-',
#  'X5-',
#  'M3-',
#  'M5-',
#  'R5+',
#  'X1+',
#  'X5+',
#  'M2-',
#  'GM5-',
#  'R2-',
#  'R3-',
#  'R5-',
#  'X2+',
#  'M1+',
#  'M2+',
#  'M3+',
#  'M4+',
#  'M5+']

# %% [markdown]
# This provides a list of irreps contained within the CIF.

# %% [markdown]
# We are going to use the "write_inp" method to make an input file to perform symmetry adapted PDF analysis. The required arguments takes are (in order):
#
# sample:
# A "sample" string to remind you what you are running. This is often just the material you are analysing. This is repeated in the output files SAPA produces.
#
# filenameformat:
# This is a string to allow Topas to iterate over the data files. This includes any path information - SAPA assumes the data is in the working directory, so you need to specify if it isn't. Your data file names should be in a format to allow for iteration, i.e. they have a consistent naming convention such as "BaTiO3_15K.xy", "BaTiO3_150K.xy". The temperatures here can be iterated over, and to tell Topas that, replace the temperature with ##n## (filenameformat = "BaTiO3_##n##K.xy")
#
# isneutron:
# Set this to True if you are using neutron data, or False for X-ray data. For this example with BaTiO3, we are using neutron data.
#
# qmax:
# The maximum value of Q used to generate the PDF data. For this data, qmax = 40.
#
# dq:
# The Q-space dampening parameter. For this data, dq = 0.033
#
# startx, finishx:
# The r-range to start and end the refinement at. For SAPA, most of the information is contained within the low-r region. For this data, set startx = 1.7 and finishx = 10.0
#
# lattice:
# This is a flag to allow lattice parameters to refine as they should for a given lattice type. This can be "C", "T", "O", "R", "H", "TC" or "M", for cubic, tetragonal, orthorhombic, rhombohedral, hexagonal, triclinic and monoclinic, respectively. For now, use lattice = "C".
#
# There are further optional arguments that can be specified. The relevant ones for today are:
#
# cycles:
# The number of cycles to perform for each irrep. The default is 300, but for time purposes, lets lower this to 100.
#
# filename:
# The default is "batch_modes.inp", but this can be changed. Obviously, it still requires the .inp file extension, whatever the name is.

# %%
struc.write_inp(sample="BaTiO3", filenameformat="BaTiO3_##n##K.xy", isneutron=True, qmax=40.0, dq=0.033, startx=1.7, finishx=10.0, lattice="C", cycles=100)
# Out:
# Creating input file...
# 120
# 120
# ...batch_modes.inp written

# %% [markdown]
# This has printed the number of modes in the input file (120 in this case), and has indicated an input file has been written. This can be viewed using jEdit, and we can go through the components of that input file later, time providing.

# %% [markdown]
# Now, we set the temperatures of our data files. (NB: these don't have to be temperatures, it is simply something to iterate over). This can be specified as a list (as below) if you don't have a regular interval between data points. Often at I15-1, we collect data at regular intervals, so we could use temps = range(start, finish + interval, interval)

# %%
temps = [15, 150, 210, 250, 293, 350, 410, 500]

# %% [markdown]
# And now, we can set the code to be run. For each temperature and irrep, this tells Topas to execute the input file with the correct modes activated. Note that this will take a long time to execute. Locking your computer, or letting it go to sleep will interrupt this process, so set the power settings to not go to sleep.

# %%
struc.execute(temps)
# Out:
# Finding Topas executables...
# Creating Monitoring File...
# Executing...
# Executing irrep GM4- for temp 15
# Completed irrep GM4- for temp 15. Process took 117.48206639289856s (1.9580344398816427 minutes)
# Estimated 5.449862524337239 hours to completion.
# Executing irrep R4- for temp 15
# Completed irrep R4- for temp 15. Process took 130.78447580337524s (2.1797412633895874 minutes)
# Estimated 5.723923056191868 hours to completion.
# Executing irrep X3- for temp 15
# Completed irrep X3- for temp 15. Process took 143.01600551605225s (2.383600091934204 minutes)
# Estimated 5.977927812271648 hours to completion.
# Executing irrep X5- for temp 15
# Completed irrep X5- for temp 15. Process took 155.6020691394806s (2.5933678189913434 minutes)
# Estimated 6.228408136367798 hours to completion.
# Executing irrep M3- for temp 15
# Completed irrep M3- for temp 15. Process took 82.13271284103394s (1.3688785473505656 minutes)
# Estimated 5.6961013744407225 hours to completion.
# Executing irrep M5- for temp 15
# Completed irrep M5- for temp 15. Process took 220.0730013847351s (3.667883356412252 minutes)
# Estimated 6.368177483081817 hours to completion.
# Executing irrep R5+ for temp 15
# Completed irrep R5+ for temp 15. Process took 80.5417468547821s (1.3423624475797018 minutes)
# Estimated 5.9393160534567295 hours to completion.
# Executing irrep X1+ for temp 15
# Completed irrep X1+ for temp 15. Process took 177.7527449131012s (2.9625457485516864 minutes)
# Estimated 6.152137904696994 hours to completion.
# Executing irrep X5+ for temp 15
# Completed irrep X5+ for temp 15. Process took 247.18360257148743s (4.11972670952479 minutes)
# Estimated 6.647419124731312 hours to completion.
# Executing irrep M2- for temp 15
# Completed irrep M2- for temp 15. Process took 153.95371556282043s (2.5658952593803406 minutes)
# Estimated 6.620736063188977 hours to completion.
# Executing irrep GM5- for temp 15
# Completed irrep GM5- for temp 15. Process took 126.82693600654602s (2.113782266775767 minutes)
# Estimated 6.483580936536645 hours to completion.
# Executing irrep R2- for temp 15
# Completed irrep R2- for temp 15. Process took 54.274173974990845s (0.9045695662498474 minutes)
# Estimated 6.101417295138041 hours to completion.
# Executing irrep R3- for temp 15
# Completed irrep R3- for temp 15. Process took 61.07347893714905s (1.0178913156191507 minutes)
# Estimated 5.798247716544021 hours to completion.
# Executing irrep R5- for temp 15
# Completed irrep R5- for temp 15. Process took 81.40811276435852s (1.3568018794059753 minutes)
# Estimated 5.598098130358589 hours to completion.
# Executing irrep X2+ for temp 15
# Completed irrep X2+ for temp 15. Process took 104.37028574943542s (1.7395047624905904 minutes)
# Estimated 5.486679530501365 hours to completion.
# Executing irrep M1+ for temp 15
# Completed irrep M1+ for temp 15. Process took 71.83398032188416s (1.197233005364736 minutes)
# Estimated 5.299704592492845 hours to completion.
# Executing irrep M2+ for temp 15
# Completed irrep M2+ for temp 15. Process took 94.85651469230652s (1.580941911538442 minutes)
# Estimated 5.189183155839739 hours to completion.
# Executing irrep M3+ for temp 15
# Completed irrep M3+ for temp 15. Process took 96.7112033367157s (1.6118533889452615 minutes)
# Estimated 5.092307469359151 hours to completion.
# Executing irrep M4+ for temp 15
# Completed irrep M4+ for temp 15. Process took 64.37252855300903s (1.072875475883484 minutes)
# Estimated 4.932356051785208 hours to completion.
# Executing irrep M5+ for temp 15
# Completed irrep M5+ for temp 15. Process took 126.48938941955566s (2.1081564903259276 minutes)
# Estimated 4.9142963086234195 hours to completion.
# Executing irrep nomodes for temp 15
# Completed irrep nomodes for temp 15. Process took 50.00236511230469s (0.8333727518717448 minutes)
# Estimated 4.745885491371155 hours to completion.
# Executing irrep GM4- for temp 150
# Completed irrep GM4- for temp 150. Process took 145.7385859489441s (2.4289764324824015 minutes)
# Estimated 4.768005499827741 hours to completion.
# Executing irrep R4- for temp 150
# Completed irrep R4- for temp 150. Process took 122.58264923095703s (2.043044153849284 minutes)
# Estimated 4.744130918225228 hours to completion.
# Executing irrep X3- for temp 150
# Completed irrep X3- for temp 150. Process took 128.9112913608551s (2.1485215226809182 minutes)
# Estimated 4.7299560606479645 hours to completion.
# Executing irrep X5- for temp 150
# Completed irrep X5- for temp 150. Process took 171.84682703018188s (2.864113783836365 minutes)
# Estimated 4.7822702918767925 hours to completion.
# Executing irrep M3- for temp 150
# Completed irrep M3- for temp 150. Process took 77.33025622367859s (1.2888376037279765 minutes)
# Estimated 4.683497886637337 hours to completion.
# Executing irrep M5- for temp 150
# Completed irrep M5- for temp 150. Process took 241.27154970169067s (4.021192495028178 minutes)
# Estimated 4.828266872197021 hours to completion.
# Executing irrep R5+ for temp 150
# Completed irrep R5+ for temp 150. Process took 82.45317316055298s (1.374219552675883 minutes)
# Estimated 4.737327003479004 hours to completion.
# Executing irrep X1+ for temp 150
# Completed irrep X1+ for temp 150. Process took 135.845308303833s (2.2640884717305503 minutes)
# Estimated 4.7221665168813365 hours to completion.
# Executing irrep X5+ for temp 150
# Completed irrep X5+ for temp 150. Process took 257.8959393501282s (4.298265655835469 minutes)
# Estimated 4.8614546596474115 hours to completion.
# Executing irrep M2- for temp 150
# Completed irrep M2- for temp 150. Process took 146.62225770950317s (2.443704295158386 minutes)
# Estimated 4.850535267544477 hours to completion.
# Executing irrep GM5- for temp 150
# Completed irrep GM5- for temp 150. Process took 96.98481678962708s (1.6164136131604512 minutes)
# Estimated 4.779153055498997 hours to completion.
# Executing irrep R2- for temp 150
# Completed irrep R2- for temp 150. Process took 59.12580442428589s (0.9854300737380981 minutes)
# Estimated 4.667442692138931 hours to completion.
# Executing irrep R3- for temp 150
# Completed irrep R3- for temp 150. Process took 62.455034017562866s (1.0409172336260477 minutes)
# Estimated 4.5649821635243155 hours to completion.
# Executing irrep R5- for temp 150
# Completed irrep R5- for temp 150. Process took 85.17691373825073s (1.4196152289708455 minutes)
# Estimated 4.491369378884633 hours to completion.
# Executing irrep X2+ for temp 150
# Completed irrep X2+ for temp 150. Process took 97.87908267974854s (1.6313180446624755 minutes)
# Estimated 4.433469129138523 hours to completion.
# Executing irrep M1+ for temp 150
# Completed irrep M1+ for temp 150. Process took 89.37156820297241s (1.489526136716207 minutes)
# Estimated 4.3688619667524335 hours to completion.
# Executing irrep M2+ for temp 150
# Completed irrep M2+ for temp 150. Process took 95.04697012901306s (1.5841161688168843 minutes)
# Estimated 4.311741870763706 hours to completion.
# Executing irrep M3+ for temp 150
# Completed irrep M3+ for temp 150. Process took 81.87620830535889s (1.3646034717559814 minutes)
# Estimated 4.244095724031456 hours to completion.
# Executing irrep M4+ for temp 150
# Completed irrep M4+ for temp 150. Process took 70.1556282043457s (1.1692604700724283 minutes)
# Estimated 4.1682764216529 hours to completion.
# Executing irrep M5+ for temp 150
# Completed irrep M5+ for temp 150. Process took 143.3880593776703s (2.389800989627838 minutes)
# Estimated 4.158216648269798 hours to completion.
# Executing irrep nomodes for temp 150
# Completed irrep nomodes for temp 150. Process took 54.36342692375183s (0.9060571153958639 minutes)
# Estimated 4.072552050550779 hours to completion.
# Executing irrep GM4- for temp 210
# Completed irrep GM4- for temp 210. Process took 154.97458219528198s (2.5829097032546997 minutes)
# Estimated 4.071412340807669 hours to completion.
# Executing irrep R4- for temp 210
# Completed irrep R4- for temp 210. Process took 124.67275953292847s (2.0778793255488077 minutes)
# Estimated 4.044646562476351 hours to completion.
# Executing irrep X3- for temp 210
# Completed irrep X3- for temp 210. Process took 112.50450372695923s (1.875075062115987 minutes)
# Estimated 4.008292343532597 hours to completion.
# Executing irrep X5- for temp 210
# Completed irrep X5- for temp 210. Process took 184.6163580417633s (3.076939300696055 minutes)
# Estimated 4.0252858757684775 hours to completion.
# Executing irrep M3- for temp 210
# Completed irrep M3- for temp 210. Process took 76.45524549484253s (1.2742540915807088 minutes)
# Estimated 3.9620247935459685 hours to completion.
# Executing irrep M5- for temp 210
# Completed irrep M5- for temp 210. Process took 235.52723813056946s (3.9254539688428243 minutes)
# Estimated 4.010981352627278 hours to completion.
# Executing irrep R5+ for temp 210
# Completed irrep R5+ for temp 210. Process took 101.65430283546448s (1.6942383805910746 minutes)
# Estimated 3.964958200814232 hours to completion.
# Executing irrep X1+ for temp 210
# Completed irrep X1+ for temp 210. Process took 138.42989420890808s (2.307164903481801 minutes)
# Estimated 3.943754926053683 hours to completion.
# Executing irrep X5+ for temp 210
# Completed irrep X5+ for temp 210. Process took 266.8974244594574s (4.448290407657623 minutes)
# Estimated 4.003741764741785 hours to completion.
# Executing irrep M2- for temp 210
# Completed irrep M2- for temp 210. Process took 160.3976275920868s (2.6732937932014464 minutes)
# Estimated 3.992576485245656 hours to completion.
# Executing irrep GM5- for temp 210
# Completed irrep GM5- for temp 210. Process took 117.01801919937134s (1.9503003199895224 minutes)
# Estimated 3.954005229816747 hours to completion.
# Executing irrep R2- for temp 210
# Completed irrep R2- for temp 210. Process took 58.61160588264465s (0.9768600980440776 minutes)
# Estimated 3.881407975841451 hours to completion.
# Executing irrep R3- for temp 210
# Completed irrep R3- for temp 210. Process took 62.65786623954773s (1.0442977706591288 minutes)
# Estimated 3.8131678149832617 hours to completion.
# Executing irrep R5- for temp 210
# Completed irrep R5- for temp 210. Process took 76.25688815116882s (1.2709481358528136 minutes)
# Estimated 3.754298209084405 hours to completion.
# Executing irrep X2+ for temp 210
# Completed irrep X2+ for temp 210. Process took 93.53016471862793s (1.558836078643799 minutes)
# Estimated 3.706094690345184 hours to completion.
# Executing irrep M1+ for temp 210
# Completed irrep M1+ for temp 210. Process took 80.55361604690552s (1.3425602674484254 minutes)
# Estimated 3.6518211747266323 hours to completion.
# Executing irrep M2+ for temp 210
# Completed irrep M2+ for temp 210. Process took 88.15137314796448s (1.4691895524660745 minutes)
# Estimated 3.6025279679799036 hours to completion.
# Executing irrep M3+ for temp 210
# Completed irrep M3+ for temp 210. Process took 75.38766503334045s (1.2564610838890076 minutes)
# Estimated 3.547679797649384 hours to completion.
# Executing irrep M4+ for temp 210
# Completed irrep M4+ for temp 210. Process took 70.42544603347778s (1.1737574338912964 minutes)
# Estimated 3.491525498281194 hours to completion.
# Executing irrep M5+ for temp 210
# Completed irrep M5+ for temp 210. Process took 125.00607442855835s (2.083434573809306 minutes)
# Estimated 3.462472483291421 hours to completion.
# Executing irrep nomodes for temp 210
# Completed irrep nomodes for temp 210. Process took 53.55525326728821s (0.8925875544548034 minutes)
# Estimated 3.400160356031524 hours to completion.
# Executing irrep GM4- for temp 250
# Completed irrep GM4- for temp 250. Process took 138.25692510604858s (2.3042820851008097 minutes)
# Estimated 3.377563986935549 hours to completion.
# Executing irrep R4- for temp 250
# Completed irrep R4- for temp 250. Process took 112.70982694625854s (1.8784971157709758 minutes)
# Estimated 3.3432361173986367 hours to completion.
# Executing irrep X3- for temp 250
# Completed irrep X3- for temp 250. Process took 116.53530311584473s (1.9422550519307455 minutes)
# Estimated 3.310642000286266 hours to completion.
# Executing irrep X5- for temp 250
# Completed irrep X5- for temp 250. Process took 182.70236897468567s (3.045039482911428 minutes)
# Estimated 3.305761318865107 hours to completion.
# Executing irrep M3- for temp 250
# Completed irrep M3- for temp 250. Process took 85.73954629898071s (1.4289924383163453 minutes)
# Estimated 3.259922524293264 hours to completion.
# Executing irrep M5- for temp 250
# Completed irrep M5- for temp 250. Process took 243.49029278755188s (4.058171546459198 minutes)
# Estimated 3.277593730247539 hours to completion.
# Executing irrep R5+ for temp 250
# Completed irrep R5+ for temp 250. Process took 89.26415395736694s (1.4877358992894492 minutes)
# Estimated 3.2328507501946553 hours to completion.
# Executing irrep X1+ for temp 250
# Completed irrep X1+ for temp 250. Process took 133.28067302703857s (2.221344550450643 minutes)
# Estimated 3.2053739027639323 hours to completion.
# Executing irrep X5+ for temp 250
# Completed irrep X5+ for temp 250. Process took 242.80779242515564s (4.046796540419261 minutes)
# Estimated 3.2181975006174155 hours to completion.
# Executing irrep M2- for temp 250
# Completed irrep M2- for temp 250. Process took 141.15954399108887s (2.352659066518148 minutes)
# Estimated 3.192076923849013 hours to completion.
# Executing irrep GM5- for temp 250
# Completed irrep GM5- for temp 250. Process took 129.96155881881714s (2.166025980313619 minutes)
# Estimated 3.1616513112643823 hours to completion.
# Executing irrep R2- for temp 250
# Completed irrep R2- for temp 250. Process took 59.515657901763916s (0.9919276316960652 minutes)
# Estimated 3.1068096709304385 hours to completion.
# Executing irrep R3- for temp 250
# Completed irrep R3- for temp 250. Process took 69.06381916999817s (1.151063652833303 minutes)
# Estimated 3.0561868147020452 hours to completion.
# Executing irrep R5- for temp 250
# Completed irrep R5- for temp 250. Process took 81.42499732971191s (1.3570832888285318 minutes)
# Estimated 3.0104385044297786 hours to completion.
# Executing irrep X2+ for temp 250
# Completed irrep X2+ for temp 250. Process took 97.57245063781738s (1.6262075106302898 minutes)
# Estimated 2.9704587434346856 hours to completion.
# Executing irrep M1+ for temp 250
# Completed irrep M1+ for temp 250. Process took 74.78534054756165s (1.2464223424593608 minutes)
# Estimated 2.92367397744612 hours to completion.
# Executing irrep M2+ for temp 250
# Completed irrep M2+ for temp 250. Process took 83.79147744178772s (1.3965246240297953 minutes)
# Estimated 2.8802913631267018 hours to completion.
# Executing irrep M3+ for temp 250
# Completed irrep M3+ for temp 250. Process took 73.55120205879211s (1.2258533676465353 minutes)
# Estimated 2.834349996783606 hours to completion.
# Executing irrep M4+ for temp 250
# Completed irrep M4+ for temp 250. Process took 78.45248579978943s (1.3075414299964905 minutes)
# Estimated 2.790458717958391 hours to completion.
# Executing irrep M5+ for temp 250
# Completed irrep M5+ for temp 250. Process took 128.2350423336029s (2.1372507055600485 minutes)
# Estimated 2.761261647772119 hours to completion.
# Executing irrep nomodes for temp 250
# Completed irrep nomodes for temp 250. Process took 54.84924077987671s (0.9141540129979452 minutes)
# Estimated 2.7115266856882307 hours to completion.
# Executing irrep GM4- for temp 293
# Completed irrep GM4- for temp 293. Process took 143.52477431297302s (2.3920795718828836 minutes)
# Estimated 2.686655980234052 hours to completion.
# Executing irrep R4- for temp 293
# Completed irrep R4- for temp 293. Process took 107.2797040939331s (1.7879950682322183 minutes)
# Estimated 2.6518367081541734 hours to completion.
# Executing irrep X3- for temp 293
# Completed irrep X3- for temp 293. Process took 108.80417799949646s (1.8134029666582743 minutes)
# Estimated 2.617527084021733 hours to completion.
# Executing irrep X5- for temp 293
# Completed irrep X5- for temp 293. Process took 183.2804708480835s (3.054674514134725 minutes)
# Estimated 2.602117473669726 hours to completion.
# Executing irrep M3- for temp 293
# Completed irrep M3- for temp 293. Process took 78.09223771095276s (1.301537295182546 minutes)
# Estimated 2.559974148695389 hours to completion.
# Executing irrep M5- for temp 293
# Completed irrep M5- for temp 293. Process took 246.0252857208252s (4.10042142868042 minutes)
# Estimated 2.5587136175764935 hours to completion.
# Executing irrep R5+ for temp 293
# Completed irrep R5+ for temp 293. Process took 79.78894829750061s (1.3298158049583435 minutes)
# Estimated 2.516906161155456 hours to completion.
# Executing irrep X1+ for temp 293
# Completed irrep X1+ for temp 293. Process took 154.81400203704834s (2.580233367284139 minutes)
# Estimated 2.492741639136116 hours to completion.
# Executing irrep X5+ for temp 293
# Completed irrep X5+ for temp 293. Process took 251.62866473197937s (4.1938110788663225 minutes)
# Estimated 2.489859841897496 hours to completion.
# Executing irrep M2- for temp 293
# Completed irrep M2- for temp 293. Process took 175.73490071296692s (2.928915011882782 minutes)
# Estimated 2.4689560383741456 hours to completion.
# Executing irrep GM5- for temp 293
# Completed irrep GM5- for temp 293. Process took 139.55077147483826s (2.325846191247304 minutes)
# Estimated 2.4397411124810837 hours to completion.
# Executing irrep R2- for temp 293
# Completed irrep R2- for temp 293. Process took 55.811094760894775s (0.9301849126815795 minutes)
# Estimated 2.3928814794123174 hours to completion.
# Executing irrep R3- for temp 293
# Completed irrep R3- for temp 293. Process took 65.63747501373291s (1.0939579168955484 minutes)
# Estimated 2.3486662912648706 hours to completion.
# Executing irrep R5- for temp 293
# Completed irrep R5- for temp 293. Process took 81.93591165542603s (1.3655985275904337 minutes)
# Estimated 2.3082151761603735 hours to completion.
# Executing irrep X2+ for temp 293
# Completed irrep X2+ for temp 293. Process took 91.65813565254211s (1.5276355942090352 minutes)
# Estimated 2.270003706570025 hours to completion.
# Executing irrep M1+ for temp 293
# Completed irrep M1+ for temp 293. Process took 76.10671043395996s (1.2684451738993328 minutes)
# Estimated 2.2291097630765706 hours to completion.
# Executing irrep M2+ for temp 293
# Completed irrep M2+ for temp 293. Process took 82.68136644363403s (1.3780227740605673 minutes)
# Estimated 2.1898184733920627 hours to completion.
# Executing irrep M3+ for temp 293
# Completed irrep M3+ for temp 293. Process took 72.53896570205688s (1.208982761700948 minutes)
# Estimated 2.1490242863870135 hours to completion.
# Executing irrep M4+ for temp 293
# Completed irrep M4+ for temp 293. Process took 81.74232220649719s (1.3623720367749532 minutes)
# Estimated 2.110244280578892 hours to completion.
# Executing irrep M5+ for temp 293
# Completed irrep M5+ for temp 293. Process took 126.61173510551453s (2.1101955850919087 minutes)
# Estimated 2.079443371520083 hours to completion.
# Executing irrep nomodes for temp 293
# Completed irrep nomodes for temp 293. Process took 54.21148157119751s (0.9035246928532918 minutes)
# Estimated 2.036492534160614 hours to completion.
# Executing irrep GM4- for temp 350
# Completed irrep GM4- for temp 350. Process took 180.11334586143494s (3.001889097690582 minutes)
# Estimated 2.0145237163290286 hours to completion.
# Executing irrep R4- for temp 350
# Completed irrep R4- for temp 350. Process took 119.65904521942139s (1.9943174203236897 minutes)
# Estimated 1.982456862301965 hours to completion.
# Executing irrep X3- for temp 350
# Completed irrep X3- for temp 350. Process took 149.27169609069824s (2.4878616015116375 minutes)
# Estimated 1.9549381623665492 hours to completion.
# Executing irrep X5- for temp 350
# Completed irrep X5- for temp 350. Process took 160.71457505226135s (2.6785762508710227 minutes)
# Estimated 1.9288840931805873 hours to completion.
# Executing irrep M3- for temp 350
# Completed irrep M3- for temp 350. Process took 75.41803526878357s (1.2569672544797261 minutes)
# Estimated 1.8899991170264254 hours to completion.
# Executing irrep M5- for temp 350
# Completed irrep M5- for temp 350. Process took 225.85484433174133s (3.764247405529022 minutes)
# Estimated 1.8728960074247183 hours to completion.
# Executing irrep R5+ for temp 350
# Completed irrep R5+ for temp 350. Process took 74.7164134979248s (1.2452735582987466 minutes)
# Estimated 1.8339865500397152 hours to completion.
# Executing irrep X1+ for temp 350
# Completed irrep X1+ for temp 350. Process took 130.92809534072876s (2.182134922345479 minutes)
# Estimated 1.8029983261048852 hours to completion.
# Executing irrep X5+ for temp 350
# Completed irrep X5+ for temp 350. Process took 215.37233638763428s (3.5895389397939046 minutes)
# Estimated 1.7830267884229358 hours to completion.
# Executing irrep M2- for temp 350
# Completed irrep M2- for temp 350. Process took 161.23057460784912s (2.687176243464152 minutes)
# Estimated 1.7554309440361706 hours to completion.
# Executing irrep GM5- for temp 350
# Completed irrep GM5- for temp 350. Process took 195.8223044872284s (3.26370507478714 minutes)
# Estimated 1.7318461123028934 hours to completion.
# Executing irrep R2- for temp 350
# Completed irrep R2- for temp 350. Process took 52.66322469711304s (0.8777204116185506 minutes)
# Estimated 1.690400532968024 hours to completion.
# Executing irrep R3- for temp 350
# Completed irrep R3- for temp 350. Process took 59.664541482925415s (0.9944090247154236 minutes)
# Estimated 1.650233549586797 hours to completion.
# Executing irrep R5- for temp 350
# Completed irrep R5- for temp 350. Process took 74.12140369415283s (1.2353567282358806 minutes)
# Estimated 1.6121166582824356 hours to completion.
# Executing irrep X2+ for temp 350
# Completed irrep X2+ for temp 350. Process took 98.23892188072205s (1.6373153646787009 minutes)
# Estimated 1.5769716180960338 hours to completion.
# Executing irrep M1+ for temp 350
# Completed irrep M1+ for temp 350. Process took 69.45201516151428s (1.157533586025238 minutes)
# Estimated 1.5388504113113257 hours to completion.
# Executing irrep M2+ for temp 350
# Completed irrep M2+ for temp 350. Process took 82.2646119594574s (1.3710768659909567 minutes)
# Estimated 1.5023798149802428 hours to completion.
# Executing irrep M3+ for temp 350
# Completed irrep M3+ for temp 350. Process took 67.87243485450745s (1.131207247575124 minutes)
# Estimated 1.464668051304856 hours to completion.
# Executing irrep M4+ for temp 350
# Completed irrep M4+ for temp 350. Process took 73.90574908256531s (1.2317624847094217 minutes)
# Estimated 1.4278551354224538 hours to completion.
# Executing irrep M5+ for temp 350
# Completed irrep M5+ for temp 350. Process took 120.4289345741272s (2.0071489095687864 minutes)
# Estimated 1.3957483050341077 hours to completion.
# Executing irrep nomodes for temp 350
# Completed irrep nomodes for temp 350. Process took 55.34746789932251s (0.9224577983220418 minutes)
# Estimated 1.3575940533699815 hours to completion.
# Executing irrep GM4- for temp 410
# Completed irrep GM4- for temp 410. Process took 171.48668026924133s (2.858111337820689 minutes)
# Estimated 1.3302134748977834 hours to completion.
# Executing irrep R4- for temp 410
# Completed irrep R4- for temp 410. Process took 116.37138199806213s (1.9395230333010356 minutes)
# Estimated 1.2977321040506165 hours to completion.
# Executing irrep X3- for temp 410
# Completed irrep X3- for temp 410. Process took 106.73379755020142s (1.7788966258366903 minutes)
# Estimated 1.2644437937388433 hours to completion.
# Executing irrep X5- for temp 410
# Completed irrep X5- for temp 410. Process took 150.5706386566162s (2.509510644276937 minutes)
# Estimated 1.2347708855663608 hours to completion.
# Executing irrep M3- for temp 410
# Completed irrep M3- for temp 410. Process took 81.62119579315186s (1.3603532632191977 minutes)
# Estimated 1.1995029270876454 hours to completion.
# Executing irrep M5- for temp 410
# Completed irrep M5- for temp 410. Process took 224.18766617774963s (3.736461102962494 minutes)
# Estimated 1.1752262982455166 hours to completion.
# Executing irrep R5+ for temp 410
# Completed irrep R5+ for temp 410. Process took 77.04534888267517s (1.2840891480445862 minutes)
# Estimated 1.1396222577283257 hours to completion.
# Executing irrep X1+ for temp 410
# Completed irrep X1+ for temp 410. Process took 136.98971796035767s (2.283161966005961 minutes)
# Estimated 1.1084551304420627 hours to completion.
# Executing irrep X5+ for temp 410
# Completed irrep X5+ for temp 410. Process took 221.53354692459106s (3.692225782076518 minutes)
# Estimated 1.082926625041314 hours to completion.
# Executing irrep M2- for temp 410
# Completed irrep M2- for temp 410. Process took 119.90508651733398s (1.998418108622233 minutes)
# Estimated 1.0502261985049528 hours to completion.
# Executing irrep GM5- for temp 410
# Completed irrep GM5- for temp 410. Process took 210.02284407615662s (3.50038073460261 minutes)
# Estimated 1.023181253279116 hours to completion.
# Executing irrep R2- for temp 410
# Completed irrep R2- for temp 410. Process took 50.52028679847717s (0.8420047799746195 minutes)
# Estimated 0.9860509642512326 hours to completion.
# Executing irrep R3- for temp 410
# Completed irrep R3- for temp 410. Process took 65.7030827999115s (1.095051379998525 minutes)
# Estimated 0.9501329026243194 hours to completion.
# Executing irrep R5- for temp 410
# Completed irrep R5- for temp 410. Process took 87.25986766815186s (1.4543311278025308 minutes)
# Estimated 0.9156648288038042 hours to completion.
# Executing irrep X2+ for temp 410
# Completed irrep X2+ for temp 410. Process took 87.69503545761108s (1.461583924293518 minutes)
# Estimated 0.8813649975492599 hours to completion.
# Executing irrep M1+ for temp 410
# Completed irrep M1+ for temp 410. Process took 70.38759922981262s (1.1731266538302103 minutes)
# Estimated 0.846324899025926 hours to completion.
# Executing irrep M2+ for temp 410
# Completed irrep M2+ for temp 410. Process took 88.27447867393494s (1.4712413112322489 minutes)
# Estimated 0.8123700481657844 hours to completion.
# Executing irrep M3+ for temp 410
# Completed irrep M3+ for temp 410. Process took 62.20978665351868s (1.0368297775586446 minutes)
# Estimated 0.7773395286334885 hours to completion.
# Executing irrep M4+ for temp 410
# Completed irrep M4+ for temp 410. Process took 71.80842351913452s (1.1968070586522421 minutes)
# Estimated 0.7429767654522168 hours to completion.
# Executing irrep M5+ for temp 410
# Completed irrep M5+ for temp 410. Process took 122.96482443809509s (2.049413740634918 minutes)
# Estimated 0.7109527310915008 hours to completion.
# Executing irrep nomodes for temp 410
# Completed irrep nomodes for temp 410. Process took 53.894609451293945s (0.8982434908548991 minutes)
# Estimated 0.676158796662376 hours to completion.
# Executing irrep GM4- for temp 500
# Completed irrep GM4- for temp 500. Process took 200.02079677581787s (3.333679946263631 minutes)
# Estimated 0.6471179606857242 hours to completion.
# Executing irrep R4- for temp 500
# Completed irrep R4- for temp 500. Process took 105.28919529914856s (1.754819921652476 minutes)
# Estimated 0.6143656258228374 hours to completion.
# Executing irrep X3- for temp 500
# Completed irrep X3- for temp 500. Process took 92.77861785888672s (1.546310297648112 minutes)
# Estimated 0.5812430095275243 hours to completion.
# Executing irrep X5- for temp 500
# Completed irrep X5- for temp 500. Process took 164.183043718338s (2.7363840619723003 minutes)
# Estimated 0.5504507847723494 hours to completion.
# Executing irrep M3- for temp 500
# Completed irrep M3- for temp 500. Process took 82.83268332481384s (1.3805447220802307 minutes)
# Estimated 0.517084971136517 hours to completion.
# Executing irrep M5- for temp 500
# Completed irrep M5- for temp 500. Process took 236.82963919639587s (3.9471606532732646 minutes)
# Estimated 0.48804835653772544 hours to completion.
# Executing irrep R5+ for temp 500
# Completed irrep R5+ for temp 500. Process took 65.52143573760986s (1.0920239289601643 minutes)
# Estimated 0.4542085123182547 hours to completion.
# Executing irrep X1+ for temp 500
# Completed irrep X1+ for temp 500. Process took 125.83513140678406s (2.0972521901130676 minutes)
# Estimated 0.4219756251787199 hours to completion.
# Executing irrep X5+ for temp 500
# Completed irrep X5+ for temp 500. Process took 195.20608353614807s (3.253434725602468 minutes)
# Estimated 0.39119013467405594 hours to completion.
# Executing irrep M2- for temp 500
# Completed irrep M2- for temp 500. Process took 126.21600723266602s (2.1036001205444337 minutes)
# Estimated 0.3587633712133109 hours to completion.
# Executing irrep GM5- for temp 500
# Completed irrep GM5- for temp 500. Process took 188.44524788856506s (3.1407541314760845 minutes)
# Estimated 0.32739731993437154 hours to completion.
# Executing irrep R2- for temp 500
# Completed irrep R2- for temp 500. Process took 52.46752905845642s (0.8744588176409404 minutes)
# Estimated 0.2936293567126652 hours to completion.
# Executing irrep R3- for temp 500
# Completed irrep R3- for temp 500. Process took 59.714282274246216s (0.9952380379041036 minutes)
# Estimated 0.2602019634611077 hours to completion.
# Executing irrep R5- for temp 500
# Completed irrep R5- for temp 500. Process took 77.8720772266388s (1.2978679537773132 minutes)
# Estimated 0.22720306094717868 hours to completion.
# Executing irrep X2+ for temp 500
# Completed irrep X2+ for temp 500. Process took 94.88253617286682s (1.5813756028811137 minutes)
# Estimated 0.1945195059938195 hours to completion.
# Executing irrep M1+ for temp 500
# Completed irrep M1+ for temp 500. Process took 73.52421998977661s (1.2254036664962769 minutes)
# Estimated 0.16173159681824334 hours to completion.
# Executing irrep M2+ for temp 500
# Completed irrep M2+ for temp 500. Process took 82.55981040000916s (1.3759968400001525 minutes)
# Estimated 0.12915569114491224 hours to completion.
# Executing irrep M3+ for temp 500
# Completed irrep M3+ for temp 500. Process took 59.206191539764404s (0.9867698589960734 minutes)
# Estimated 0.09657871820469094 hours to completion.
# Executing irrep M4+ for temp 500
# Completed irrep M4+ for temp 500. Process took 66.1985855102539s (1.1033097585042317 minutes)
# Estimated 0.06421949394256714 hours to completion.
# Executing irrep M5+ for temp 500
# Completed irrep M5+ for temp 500. Process took 114.57312393188477s (1.9095520655314127 minutes)
# Estimated 0.03210804709576006 hours to completion.
# Executing irrep nomodes for temp 500
# Completed irrep nomodes for temp 500. Process took 52.880807638168335s (0.8813467939694722 minutes)
# Estimated 0.0 hours to completion.

# %% [markdown]
# Occasionally, things can interrupt the refinement process, or cause it to hang (e.g. locking your computer). The execute script writes a file to keep track of the temperature and irrep combinations it has and hasn't ran so far, and this can be used to restart the refinement.

# %%
#struc.restart()

# %% [markdown]
# ## Part 2 - Post Execution

# %% [markdown]
# Sometimes something can go wrong with an individual irrep/temp combo, but not interrupt the overall SAPA run. An indicator of this is that the ycalc and yobs files for these runs haven't been generated. Missing files causes problems with the HDF5 file creation. The following script checks that all the expected files are there, and if any are found to be missing, it re-runs them.

# %%
struc.file_check(temps, cycles=100, verbose=False) #re-run a couple times to make sure

# %% [markdown]
# SAPA generates a large amount of files, which can be quite cumbersome to deal with. To make dealing with SAPA data more straightforward, we place all the data in these files into a structured file format (HDF5). The file is structured in the same way for every SAPA run, meaning analysis is more repeatable.

# %%
struc.create_hdf5(temps)

# %% [markdown]
# We are still left with the large number of files however. The following script removes them and (optionally) compresses them into an archive.

# %%
struc.cleanup() # optionally set create_zip = False
# Out:
# Creating zip file...
# ...Zip file written.
# Deleting .txt files...
# ...Clean up complete.
